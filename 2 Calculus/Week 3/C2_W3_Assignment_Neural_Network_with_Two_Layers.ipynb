# %% [markdown]
# # Neural Network with Two Layers
#
# Welcome to your week three programming assignment. You are ready to build a neural network with two layers and train it to solve a classification problem.
#
# **After this assignment, you will be able to:**
#
# - Implement a neural network with two layers to a classification problem
# - Implement forward propagation using matrix multiplication
# - Perform backward propagation

# %% [markdown]
# # Table of Contents
#
# - [ 1 - Classification Problem](#1)
# - [ 2 - Neural Network Model with Two Layers](#2)
#   - [ 2.1 - Neural Network Model with Two Layers for a Single Training Example](#2.1)
#   - [ 2.2 - Neural Network Model with Two Layers for Multiple Training Examples](#2.2)
#   - [ 2.3 - Cost Function and Training](#2.3)
#   - [ 2.4 - Dataset](#2.4)
#   - [ 2.5 - Define Activation Function](#2.5)
#     - [ Exercise 1](#ex01)
# - [ 3 - Implementation of the Neural Network Model with Two Layers](#3)
#   - [ 3.1 - Defining the Neural Network Structure](#3.1)
#     - [ Exercise 2](#ex02)
#   - [ 3.2 - Initialize the Model's Parameters](#3.2)
#     - [ Exercise 3](#ex03)
#   - [ 3.3 - The Loop](#3.3)
#     - [ Exercise 4](#ex04)
#     - [ Exercise 5](#ex05)
#     - [ Exercise 6](#ex06)
#   - [ 3.4 - Integrate parts 3.1, 3.2 and 3.3 in nn_model()](#3.4)
#     - [ Exercise 7](#ex07)
#     - [ Exercise 8](#ex08)
# - [ 4 - Optional: Other Dataset](#4)

# %% [markdown]
# ## Packages
#
# First, import all the packages you will need during this assignment.

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import colors
# A function to create a dataset.
from sklearn.datasets import make_blobs

# Output of plotting commands is displayed inline within the Jupyter notebook.
# %matplotlib inline 

# Set a seed so that the results are consistent.
np.random.seed(3)

# %% [markdown]
# Load the unit tests defined for this notebook.

# %%
import w3_unittest

# %% [markdown]
# <a name='1'></a>
# ## 1 - Classification Problem

# %% [markdown]
# In one of the labs this week, you trained a neural network with a single perceptron, performing forward and backward propagation. That simple structure was enough to solve a "linear" classification problem - finding a straight line in a plane that would serve as a decision boundary to separate two classes.
#
# Imagine that now you have a more complicated problem: you still have two classes, but one line will not be enough to separate them.

# %%
fig, ax = plt.subplots()
xmin, xmax = -0.2, 1.4
x_line = np.arange(xmin, xmax, 0.1)
# Data points (observations) from two classes.
ax.scatter(0, 0, color="r")
ax.scatter(0, 1, color="b")
ax.scatter(1, 0, color="b")
ax.scatter(1, 1, color="r")
ax.set_xlim([xmin, xmax])
ax.set_ylim([-0.1, 1.1])
ax.set_xlabel('$x_1$')
ax.set_ylabel('$x_2$')
# Example of the lines which can be used as a decision boundary to separate two classes.
ax.plot(x_line, -1 * x_line + 1.5, color="black")
ax.plot(x_line, -1 * x_line + 0.5, color="black")
plt.plot()
# Out:
# []

# %% [markdown]
# This logic can appear in many applications. For example, if you train a model to predict whether you should buy a house knowing its size and the year it was built. A big new house will not be affordable, while a small old house will not be worth buying. So, you might be interested in either a big old house, or a small new house.
#
# The one perceptron neural network is not enough to solve such classification problem. Let's look at how you can adjust that model to find the solution.
#
# In the plot above, two lines can serve as a decision boundary. Your intuition might tell you that you should also increase the number of perceptrons. And that is absolutely right! You need to feed your data points (coordinates $x_1$, $x_2$) into two nodes separately and then unify them somehow with another one to make a decision.
#
# Now let's figure out the details, build and train your first multi-layer neural network!

# %% [markdown]
# <a name='2'></a>
# ## 2 - Neural Network Model with Two Layers

# %% [markdown]
# <a name='2.1'></a>
# ### 2.1 - Neural Network Model with Two Layers for a Single Training Example

# %% [markdown]
# <img src="images/nn_model_2_layers.png" style="width:1000px;">

# %% [markdown]
# The input and output layers of the neural network are the same as for one perceptron model, but there is a **hidden layer** now in between them. The training examples $x^{(i)}=\begin{bmatrix}x_1^{(i)} \\ x_2^{(i)}\end{bmatrix}$ from the input layer of size $n_x = 2$ are first fed into the hidden layer of size $n_h = 2$. They are simultaneously fed into the first perceptron with weights $W_1^{[1]}=\begin{bmatrix}w_{1,1}^{[1]} & w_{2,1}^{[1]}\end{bmatrix}$, bias  $b_1^{[1]}$; and into the second perceptron with weights $W_2^{[1]}=\begin{bmatrix}w_{1,2}^{[1]} & w_{2,2}^{[1]}\end{bmatrix}$, bias $b_2^{[1]}$. The integer in the square brackets $^{[1]}$ denotes the layer number, because there are two layers now with their own parameters and outputs, which need to be distinguished.
#
# \begin{align}
# z_1^{[1](i)} &= w_{1,1}^{[1]} x_1^{(i)} + w_{2,1}^{[1]} x_2^{(i)} + b_1^{[1]} = W_1^{[1]}x^{(i)} + b_1^{[1]},\\
# z_2^{[1](i)} &= w_{1,2}^{[1]} x_1^{(i)} + w_{2,2}^{[1]} x_2^{(i)} + b_2^{[1]} = W_2^{[1]}x^{(i)} + b_2^{[1]}.\tag{1}
# \end{align}
#
# These expressions for one training example $x^{(i)}$ can be rewritten in a matrix form :
#
# $$z^{[1](i)} = W^{[1]} x^{(i)} + b^{[1]},\tag{2}$$
#
# where
#
# &emsp; &emsp; $z^{[1](i)} = \begin{bmatrix}z_1^{[1](i)} \\ z_2^{[1](i)}\end{bmatrix}$ is vector of size $\left(n_h \times 1\right) = \left(2 \times 1\right)$;
#
# &emsp; &emsp; $W^{[1]} = \begin{bmatrix}W_1^{[1]} \\ W_2^{[1]}\end{bmatrix} =
# \begin{bmatrix}w_{1,1}^{[1]} & w_{2,1}^{[1]} \\ w_{1,2}^{[1]} & w_{2,2}^{[1]}\end{bmatrix}$ is matrix of size $\left(n_h \times n_x\right) = \left(2 \times 2\right)$;
#
# &emsp; &emsp; $b^{[1]} = \begin{bmatrix}b_1^{[1]} \\ b_2^{[1]}\end{bmatrix}$ is vector of size $\left(n_h \times 1\right) = \left(2 \times 1\right)$.

# %% [markdown]
# Next, the hidden layer activation function needs to be applied for each of the elements in the vector $z^{[1](i)}$. Various activation functions can be used here and in this model you will take the sigmoid function $\sigma\left(x\right) = \frac{1}{1 + e^{-x}}$. Remember that its derivative is $\frac{d\sigma}{dx} = \sigma\left(x\right)\left(1-\sigma\left(x\right)\right)$. The output of the hidden layer is a vector of size $\left(n_h \times 1\right) = \left(2 \times 1\right)$:
#
# $$a^{[1](i)} = \sigma\left(z^{[1](i)}\right) =
# \begin{bmatrix}\sigma\left(z_1^{[1](i)}\right) \\ \sigma\left(z_2^{[1](i)}\right)\end{bmatrix}.\tag{3}$$
#
# Then the hidden layer output gets fed into the output layer of size $n_y = 1$. This was covered in the previous lab, the only difference are: $a^{[1](i)}$ is taken instead of $x^{(i)}$ and layer notation $^{[2]}$ appears to identify all parameters and outputs:
#
# $$z^{[2](i)} = w_1^{[2]} a_1^{[1](i)} + w_2^{[2]} a_2^{[1](i)} + b^{[2]}= W^{[2]} a^{[1](i)} + b^{[2]},\tag{4}$$
#
# &emsp; &emsp; $z^{[2](i)}$ and $b^{[2]}$ are scalars for this model, as $\left(n_y \times 1\right) = \left(1 \times 1\right)$;
#
# &emsp; &emsp; $W^{[2]} = \begin{bmatrix}w_1^{[2]} & w_2^{[2]}\end{bmatrix}$ is vector of size $\left(n_y \times n_h\right) = \left(1 \times 2\right)$.
#
# Finally, the same sigmoid function is used as the output layer activation function:
#
# $$a^{[2](i)} = \sigma\left(z^{[2](i)}\right).\tag{5}$$
#
# Mathematically the two layer neural network model for each training example $x^{(i)}$ can be written with the expressions $(2) - (5)$. Let's rewrite them next to each other for convenience:
#
# \begin{align}
# z^{[1](i)} &= W^{[1]} x^{(i)} + b^{[1]},\\
# a^{[1](i)} &= \sigma\left(z^{[1](i)}\right),\\
# z^{[2](i)} &= W^{[2]} a^{[1](i)} + b^{[2]},\\
# a^{[2](i)} &= \sigma\left(z^{[2](i)}\right).\\
# \tag{6}
# \end{align}
#
# Note, that all of the parameters to be trained in the model are without $^{(i)}$ index - they are independent on the input data.

# %% [markdown]
# Finally, the predictions for some example $x^{(i)}$ can be made taking the output $a^{[2](i)}$ and calculating $\hat{y}$ as: $\hat{y} = \begin{cases} 1 & \mbox{if } a^{[2](i)} > 0.5, \\ 0 & \mbox{otherwise }. \end{cases}$.

# %% [markdown]
# <a name='2.2'></a>
# ### 2.2 - Neural Network Model with Two Layers for Multiple Training Examples

# %% [markdown]
# Similarly to the single perceptron model, $m$ training examples can be organised in a matrix $X$ of a shape ($2 \times m$), putting $x^{(i)}$ into columns. Then the model $(6)$ can be rewritten in terms of matrix multiplications:
#
# \begin{align}
# Z^{[1]} &= W^{[1]} X + b^{[1]},\\
# A^{[1]} &= \sigma\left(Z^{[1]}\right),\\
# Z^{[2]} &= W^{[2]} A^{[1]} + b^{[2]},\\
# A^{[2]} &= \sigma\left(Z^{[2]}\right),\\
# \tag{7}
# \end{align}
#
# where $b^{[1]}$ is broadcasted to the matrix of size $\left(n_h \times m\right) = \left(2 \times m\right)$ and $b^{[2]}$ to the vector of size $\left(n_y \times m\right) = \left(1 \times m\right)$. It would be a good exercise for you to have a look at the expressions $(7)$ and check that sizes of the matrices will actually match to perform required multiplications.
#
# You have derived expressions to perform forward propagation. Time to evaluate your model and train it.

# %% [markdown]
# <a name='2.3'></a>
# ### 2.3 - Cost Function and Training

# %% [markdown]
# For the evaluation of this simple neural network you can use the same cost function as for the single perceptron case - log loss function. Originally initialized weights were just some random values, now you need to perform training of the model: find such set of parameters $W^{[1]}$, $b^{[1]}$, $W^{[2]}$, $b^{[2]}$, that will minimize the cost function.
#
# Like in the previous example of a single perceptron neural network, the cost function can be written as:
#
# $$\mathcal{L}\left(W^{[1]}, b^{[1]}, W^{[2]}, b^{[2]}\right) = \frac{1}{m}\sum_{i=1}^{m} L\left(W^{[1]}, b^{[1]}, W^{[2]}, b^{[2]}\right) =  \frac{1}{m}\sum_{i=1}^{m}  \large\left(\small - y^{(i)}\log\left(a^{[2](i)}\right) - (1-y^{(i)})\log\left(1- a^{[2](i)}\right)  \large  \right), \small\tag{8}$$
#
# where $y^{(i)} \in \{0,1\}$ are the original labels and $a^{[2](i)}$ are the continuous output values of the forward propagation step (elements of array $A^{[2]}$).
#
# To minimize it, you can use gradient descent, updating the parameters with the following expressions:
#
# \begin{align}
# W^{[1]} &= W^{[1]} - \alpha \frac{\partial \mathcal{L} }{ \partial W^{[1]} },\\
# b^{[1]} &= b^{[1]} - \alpha \frac{\partial \mathcal{L} }{ \partial b^{[1]} },\\
# W^{[2]} &= W^{[2]} - \alpha \frac{\partial \mathcal{L} }{ \partial W^{[2]} },\\
# b^{[2]} &= b^{[2]} - \alpha \frac{\partial \mathcal{L} }{ \partial b^{[2]} },\\
# \tag{9}
# \end{align}
#
# where $\alpha$ is the learning rate.

# %% [markdown]
# To perform training of the model you need to calculate now $\frac{\partial \mathcal{L} }{ \partial W^{[1]}}$, $\frac{\partial \mathcal{L} }{ \partial b^{[1]}}$, $\frac{\partial \mathcal{L} }{ \partial W^{[2]}}$, $\frac{\partial \mathcal{L} }{ \partial b^{[2]}}$.
#
# Let's start from the end of the neural network. You can rewrite here the corresponding expressions for $\frac{\partial \mathcal{L} }{ \partial W }$ and $\frac{\partial \mathcal{L} }{ \partial b }$ from the single perceptron neural network:
#
# \begin{align}
# \frac{\partial \mathcal{L} }{ \partial W } &=
# \frac{1}{m}\left(A-Y\right)X^T,\\
# \frac{\partial \mathcal{L} }{ \partial b } &=
# \frac{1}{m}\left(A-Y\right)\mathbf{1},\\
# \end{align}
#
# where $\mathbf{1}$ is just a ($m \times 1$) vector of ones. Your one perceptron is in the second layer now, so $W$ will be exchanged with $W^{[2]}$, $b$ with $b^{[2]}$, $A$ with $A^{[2]}$, $X$ with $A^{[1]}$:
#
# \begin{align}
# \frac{\partial \mathcal{L} }{ \partial W^{[2]} } &=
# \frac{1}{m}\left(A^{[2]}-Y\right)\left(A^{[1]}\right)^T,\\
# \frac{\partial \mathcal{L} }{ \partial b^{[2]} } &=
# \frac{1}{m}\left(A^{[2]}-Y\right)\mathbf{1}.\\
# \tag{10}
# \end{align}

# %% [markdown]
# Let's now find $\frac{\partial \mathcal{L} }{ \partial W^{[1]}} =
# \begin{bmatrix}
# \frac{\partial \mathcal{L} }{ \partial w_{1,1}^{[1]}} & \frac{\partial \mathcal{L} }{ \partial w_{2,1}^{[1]}} \\
# \frac{\partial \mathcal{L} }{ \partial w_{1,2}^{[1]}} & \frac{\partial \mathcal{L} }{ \partial w_{2,2}^{[1]}} \end{bmatrix}$. It was shown in the videos that $$\frac{\partial \mathcal{L} }{ \partial w_{1,1}^{[1]}}=\frac{1}{m}\sum_{i=1}^{m} \left(
# \left(a^{[2](i)} - y^{(i)}\right)
# w_1^{[2]}
# \left(a_1^{[1](i)}\left(1-a_1^{[1](i)}\right)\right)
# x_1^{(i)}\right)\tag{11}$$
#
# If you do this accurately for each of the elements $\frac{\partial \mathcal{L} }{ \partial W^{[1]}}$, you will get the following matrix:
#
# $$\frac{\partial \mathcal{L} }{ \partial W^{[1]}} = \begin{bmatrix}
# \frac{\partial \mathcal{L} }{ \partial w_{1,1}^{[1]}} & \frac{\partial \mathcal{L} }{ \partial w_{2,1}^{[1]}} \\
# \frac{\partial \mathcal{L} }{ \partial w_{1,2}^{[1]}} & \frac{\partial \mathcal{L} }{ \partial w_{2,2}^{[1]}} \end{bmatrix}$$
# $$= \frac{1}{m}\begin{bmatrix}
# \sum_{i=1}^{m} \left( \left(a^{[2](i)} - y^{(i)}\right) w_1^{[2]} \left(a_1^{[1](i)}\left(1-a_1^{[1](i)}\right)\right)
# x_1^{(i)}\right) &
# \sum_{i=1}^{m} \left( \left(a^{[2](i)} - y^{(i)}\right) w_1^{[2]} \left(a_1^{[1](i)}\left(1-a_1^{[1](i)}\right)\right)
# x_2^{(i)}\right)  \\
# \sum_{i=1}^{m} \left( \left(a^{[2](i)} - y^{(i)}\right) w_2^{[2]} \left(a_2^{[1](i)}\left(1-a_2^{[1](i)}\right)\right)
# x_1^{(i)}\right) &
# \sum_{i=1}^{m} \left( \left(a^{[2](i)} - y^{(i)}\right) w_2^{[2]} \left(a_2^{[1](i)}\left(1-a_2^{[1](i)}\right)\right)
# x_2^{(i)}\right)\end{bmatrix}\tag{12}$$

# %% [markdown]
# Looking at this, you can notice that all terms and indices somehow are very consistent, so it all can be unified into a matrix form. And that's true! $\left(W^{[2]}\right)^T = \begin{bmatrix}w_1^{[2]} \\ w_2^{[2]}\end{bmatrix}$ of size $\left(n_h \times n_y\right) = \left(2 \times 1\right)$ can be multiplied with the vector $A^{[2]} - Y$ of size $\left(n_y \times m\right) = \left(1 \times m\right)$, resulting in a matrix of size $\left(n_h \times m\right) = \left(2 \times m\right)$:
#
# $$\left(W^{[2]}\right)^T \left(A^{[2]} - Y\right)=
# \begin{bmatrix}w_1^{[2]} \\ w_2^{[2]}\end{bmatrix}
# \begin{bmatrix}\left(a^{[2](1)} - y^{(1)}\right) &  \cdots & \left(a^{[2](m)} - y^{(m)}\right)\end{bmatrix}
# =\begin{bmatrix}
# \left(a^{[2](1)} - y^{(1)}\right) w_1^{[2]} & \cdots & \left(a^{[2](m)} - y^{(m)}\right) w_1^{[2]} \\
# \left(a^{[2](1)} - y^{(1)}\right) w_2^{[2]} & \cdots & \left(a^{[2](m)} - y^{(m)}\right) w_2^{[2]} \end{bmatrix}$$.
#
# Now taking matrix $A^{[1]}$ of the same size $\left(n_h \times m\right) = \left(2 \times m\right)$,
#
# $$A^{[1]}
# =\begin{bmatrix}
# a_1^{[1](1)} & \cdots & a_1^{[1](m)} \\
# a_2^{[1](1)} & \cdots & a_2^{[1](m)} \end{bmatrix},$$
#
# you can calculate:
#
# $$A^{[1]}\cdot\left(1-A^{[1]}\right)
# =\begin{bmatrix}
# a_1^{[1](1)}\left(1 - a_1^{[1](1)}\right) & \cdots & a_1^{[1](m)}\left(1 - a_1^{[1](m)}\right) \\
# a_2^{[1](1)}\left(1 - a_2^{[1](1)}\right) & \cdots & a_2^{[1](m)}\left(1 - a_2^{[1](m)}\right) \end{bmatrix},$$
#
# where "$\cdot$" denotes **element by element** multiplication.

# %% [markdown]
# With the element by element multiplication,
#
# $$\left(W^{[2]}\right)^T \left(A^{[2]} - Y\right)\cdot \left(A^{[1]}\cdot\left(1-A^{[1]}\right)\right)=\begin{bmatrix}
# \left(a^{[2](1)} - y^{(1)}\right) w_1^{[2]}\left(a_1^{[1](1)}\left(1 - a_1^{[1](1)}\right)\right) & \cdots & \left(a^{[2](m)} - y^{(m)}\right) w_1^{[2]}\left(a_1^{[1](m)}\left(1 - a_1^{[1](m)}\right)\right) \\
# \left(a^{[2](1)} - y^{(1)}\right) w_2^{[2]}\left(a_2^{[1](1)}\left(1 - a_2^{[1](1)}\right)\right) & \cdots & \left(a^{[2](m)} - y^{(m)}\right) w_2^{[2]} \left(a_2^{[1](m)}\left(1 - a_2^{[1](m)}\right)\right) \end{bmatrix}.$$
#
# If you perform matrix multiplication with $X^T$ of size $\left(m \times n_x\right) = \left(m \times 2\right)$, you will get matrix of size $\left(n_h \times n_x\right) = \left(2 \times 2\right)$:
#
# $$\left(\left(W^{[2]}\right)^T \left(A^{[2]} - Y\right)\cdot \left(A^{[1]}\cdot\left(1-A^{[1]}\right)\right)\right)X^T =
# \begin{bmatrix}
# \left(a^{[2](1)} - y^{(1)}\right) w_1^{[2]}\left(a_1^{[1](1)}\left(1 - a_1^{[1](1)}\right)\right) & \cdots & \left(a^{[2](m)} - y^{(m)}\right) w_1^{[2]}\left(a_1^{[1](m)}\left(1 - a_1^{[1](m)}\right)\right) \\
# \left(a^{[2](1)} - y^{(1)}\right) w_2^{[2]}\left(a_2^{[1](1)}\left(1 - a_2^{[1](1)}\right)\right) & \cdots & \left(a^{[2](m)} - y^{(m)}\right) w_2^{[2]} \left(a_2^{[1](m)}\left(1 - a_2^{[1](m)}\right)\right) \end{bmatrix}
# \begin{bmatrix}
# x_1^{(1)} & x_2^{(1)} \\
# \cdots & \cdots \\
# x_1^{(m)} & x_2^{(m)}
# \end{bmatrix}$$
# $$=\begin{bmatrix}
# \sum_{i=1}^{m} \left( \left(a^{[2](i)} - y^{(i)}\right) w_1^{[2]} \left(a_1^{[1](i)}\left(1 - a_1^{[1](i)}\right) \right)
# x_1^{(i)}\right) &
# \sum_{i=1}^{m} \left( \left(a^{[2](i)} - y^{(i)}\right) w_1^{[2]} \left(a_1^{[1](i)}\left(1-a_1^{[1](i)}\right)\right)
# x_2^{(i)}\right)  \\
# \sum_{i=1}^{m} \left( \left(a^{[2](i)} - y^{(i)}\right) w_2^{[2]} \left(a_2^{[1](i)}\left(1-a_2^{[1](i)}\right)\right)
# x_1^{(i)}\right) &
# \sum_{i=1}^{m} \left( \left(a^{[2](i)} - y^{(i)}\right) w_2^{[2]} \left(a_2^{[1](i)}\left(1-a_2^{[1](i)}\right)\right)
# x_2^{(i)}\right)\end{bmatrix}$$
#
# This is exactly like in the expression $(12)$! So, $\frac{\partial \mathcal{L} }{ \partial W^{[1]}}$ can be written as a mixture of multiplications:
#
# $$\frac{\partial \mathcal{L} }{ \partial W^{[1]}} = \frac{1}{m}\left(\left(W^{[2]}\right)^T \left(A^{[2]} - Y\right)\cdot \left(A^{[1]}\cdot\left(1-A^{[1]}\right)\right)\right)X^T\tag{13},$$
#
# where "$\cdot$" denotes element by element multiplications.

# %% [markdown]
# Vector $\frac{\partial \mathcal{L} }{ \partial b^{[1]}}$ can be found very similarly, but the last terms in the chain rule will be equal to $1$, i.e. $\frac{\partial z_1^{[1](i)}}{ \partial b_1^{[1]}} = 1$. Thus,
#
# $$\frac{\partial \mathcal{L} }{ \partial b^{[1]}} = \frac{1}{m}\left(\left(W^{[2]}\right)^T \left(A^{[2]} - Y\right)\cdot \left(A^{[1]}\cdot\left(1-A^{[1]}\right)\right)\right)\mathbf{1},\tag{14}$$
#
# where $\mathbf{1}$ is a ($m \times 1$) vector of ones.
#
# Expressions $(10)$, $(13)$ and $(14)$ can be used for the parameters update $(9)$ performing backward propagation:
#
# \begin{align}
# \frac{\partial \mathcal{L} }{ \partial W^{[2]} } &=
# \frac{1}{m}\left(A^{[2]}-Y\right)\left(A^{[1]}\right)^T,\\
# \frac{\partial \mathcal{L} }{ \partial b^{[2]} } &=
# \frac{1}{m}\left(A^{[2]}-Y\right)\mathbf{1},\\
# \frac{\partial \mathcal{L} }{ \partial W^{[1]}} &= \frac{1}{m}\left(\left(W^{[2]}\right)^T \left(A^{[2]} - Y\right)\cdot \left(A^{[1]}\cdot\left(1-A^{[1]}\right)\right)\right)X^T,\\
# \frac{\partial \mathcal{L} }{ \partial b^{[1]}} &= \frac{1}{m}\left(\left(W^{[2]}\right)^T \left(A^{[2]} - Y\right)\cdot \left(A^{[1]}\cdot\left(1-A^{[1]}\right)\right)\right)\mathbf{1},\\
# \tag{15}
# \end{align}
#
# where $\mathbf{1}$ is a ($m \times 1$) vector of ones.

# %% [markdown]
# So, to understand deeply and properly how neural networks perform and get trained, **you do need knowledge of linear algebra and calculus joined together**! But do not worry! All together it is not that scary if you do it step by step accurately with understanding of maths.
#
# Time to implement this all in the code!

# %% [markdown]
# <a name='2.2'></a>
# ### 2.2 - Dataset
#
# First, let's get the dataset you will work on. The following code will create $m=2000$ data points $(x_1, x_2)$ and save them in the `NumPy` array `X` of a shape $(2 \times m)$ (in the columns of the array). The labels ($0$: blue, $1$: red) will be saved in the `NumPy` array `Y` of a shape $(1 \times m)$.

# %%
m = 2000
samples, labels = make_blobs(n_samples=m, 
                             centers=([2.5, 3], [6.7, 7.9], [2.1, 7.9], [7.4, 2.8]), 
                             cluster_std=1.1,
                             random_state=0)
labels[(labels == 0) | (labels == 1)] = 1
labels[(labels == 2) | (labels == 3)] = 0
X = np.transpose(samples)
Y = labels.reshape((1, m))

plt.scatter(X[0, :], X[1, :], c=Y, cmap=colors.ListedColormap(['blue', 'red']));

print ('The shape of X is: ' + str(X.shape))
print ('The shape of Y is: ' + str(Y.shape))
print ('I have m = %d training examples!' % (m))
# Out:
# The shape of X is: (2, 2000)
# The shape of Y is: (1, 2000)
# I have m = 2000 training examples!

# %% [markdown]
# <a name='2.3'></a>
# ### 2.3 - Define Activation Function

# %% [markdown]
# <a name='ex01'></a>
# ### Exercise 1
#
# Define sigmoid activation function $\sigma\left(z\right) =\frac{1}{1+e^{-z}} $.

# %%
def sigmoid(z):
    ### START CODE HERE ### (~ 1 line of code)
    res = 1 / (1 + np.exp(-z))
    ### END CODE HERE ###
    
    return res

# %%
print("sigmoid(-2) = " + str(sigmoid(-2)))
print("sigmoid(0) = " + str(sigmoid(0)))
print("sigmoid(3.5) = " + str(sigmoid(3.5)))
# Out:
# sigmoid(-2) = 0.11920292202211755
# sigmoid(0) = 0.5
# sigmoid(3.5) = 0.9706877692486436

# %% [markdown]
# ##### __Expected Output__
#
# Note: the values may vary in the last decimal places.
#
# ```Python
# sigmoid(-2) = 0.11920292202211755
# sigmoid(0) = 0.5
# sigmoid(3.5) = 0.9706877692486436
# ```

# %%
w3_unittest.test_sigmoid(sigmoid)
# Out:
#  All tests passed

# %% [markdown]
# <a name='3'></a>
# ## 3 - Implementation of the Neural Network Model with Two Layers

# %% [markdown]
# <a name='3.1'></a>
# ### 3.1 - Defining the Neural Network Structure

# %% [markdown]
# <a name='ex02'></a>
# ### Exercise 2
#
# Define three variables:
# - `n_x`: the size of the input layer
# - `n_h`: the size of the hidden layer (set it equal to 2 for now)
# - `n_y`: the size of the output layer

# %% [markdown]
# <details>
# <summary>
#     <font size="3" color="darkgreen"><b>Hint</b></font>
# </summary>
# <p>
# <ul>
#     Use shapes of X and Y to find n_x and n_y:
#     <li>the size of the input layer n_x equals to the size of the input vectors placed in the columns of the array X,</li>
#     <li>the outpus for each of the data point will be saved in the columns of the the array Y.</li>
# </ul>
# </p>

# %%
# GRADED FUNCTION: layer_sizes

def layer_sizes(X, Y):
    """
    Arguments:
    X -- input dataset of shape (input size, number of examples)
    Y -- labels of shape (output size, number of examples)
    
    Returns:
    n_x -- the size of the input layer
    n_h -- the size of the hidden layer
    n_y -- the size of the output layer
    """
    ### START CODE HERE ### (~ 3 lines of code)
    # Size of input layer.
    n_x = X.shape[0]
    # Size of hidden layer.
    n_h = 2
    # Size of output layer.
    n_y = Y.shape[0]
    ### END CODE HERE ###
    return (n_x, n_h, n_y)

# %%
(n_x, n_h, n_y) = layer_sizes(X, Y)
print("The size of the input layer is: n_x = " + str(n_x))
print("The size of the hidden layer is: n_h = " + str(n_h))
print("The size of the output layer is: n_y = " + str(n_y))
# Out:
# The size of the input layer is: n_x = 2
# The size of the hidden layer is: n_h = 2
# The size of the output layer is: n_y = 1

# %% [markdown]
# ##### __Expected Output__
#
# ```Python
# The size of the input layer is: n_x = 2
# The size of the hidden layer is: n_h = 2
# The size of the output layer is: n_y = 1
# ```

# %%
w3_unittest.test_layer_sizes(layer_sizes)
# Out:
#  All tests passed

# %% [markdown]
# <a name='3.2'></a>
# ### 3.2 - Initialize the Model's Parameters

# %% [markdown]
# <a name='ex03'></a>
# ### Exercise 3
#
# Implement the function `initialize_parameters()`.
#
# **Instructions**:
# - Make sure your parameters' sizes are right. Refer to the neural network figure above if needed.
# - You will initialize the weights matrix with random values.
#     - Use: `np.random.randn(a,b) * 0.01` to randomly initialize a matrix of shape (a,b).
# - You will initialize the bias vector as zeros.
#     - Use: `np.zeros((a,b))` to initialize a matrix of shape (a,b) with zeros.

# %%
# GRADED FUNCTION: initialize_parameters

def initialize_parameters(n_x, n_h, n_y):
    """
    Argument:
    n_x -- size of the input layer
    n_h -- size of the hidden layer
    n_y -- size of the output layer
    
    Returns:
    params -- python dictionary containing your parameters:
                    W1 -- weight matrix of shape (n_h, n_x)
                    b1 -- bias vector of shape (n_h, 1)
                    W2 -- weight matrix of shape (n_y, n_h)
                    b2 -- bias vector of shape (n_y, 1)
    """
    
    ### START CODE HERE ### (~ 4 lines of code)
    W1 = np.random.randn(n_h, n_x) * 0.01
    b1 = np.zeros((n_h, 1))
    W2 = np.random.randn(n_y, n_h) * 0.01
    b2 = np.zeros((n_y, 1))
    ### END CODE HERE ###
    
    assert (W1.shape == (n_h, n_x))
    assert (b1.shape == (n_h, 1))
    assert (W2.shape == (n_y, n_h))
    assert (b2.shape == (n_y, 1))
    
    parameters = {"W1": W1,
                  "b1": b1,
                  "W2": W2,
                  "b2": b2}
    
    return parameters

# %%
parameters = initialize_parameters(n_x, n_h, n_y)

print("W1 = " + str(parameters["W1"]))
print("b1 = " + str(parameters["b1"]))
print("W2 = " + str(parameters["W2"]))
print("b2 = " + str(parameters["b2"]))
# Out:
# W1 = [[-0.00082741 -0.00627001]
#  [-0.00043818 -0.00477218]]
# b1 = [[0.]
#  [0.]]
# W2 = [[-0.01313865  0.00884622]]
# b2 = [[0.]]

# %% [markdown]
# ##### __Expected Output__
# Note: the elements of the arrays W1 and W2 maybe be different due to random initialization. You can try to restart the kernel to get the same values.
#
# ```Python
# W1 = [[ 0.01788628  0.0043651 ]
#  [ 0.00096497 -0.01863493]]
# b1 = [[0.]
#  [0.]]
# W2 = [[-0.00277388 -0.00354759]]
# b2 = [[0.]]
# ```

# %%
# Note: 
# Actual values are not checked here in the unit tests (due to random initialization).
w3_unittest.test_initialize_parameters(initialize_parameters)
# Out:
#  All tests passed

# %% [markdown]
# <a name='3.3'></a>
# ### 3.3 - The Loop

# %% [markdown]
# <a name='ex04'></a>
# ### Exercise 4
#
# Implement `forward_propagation()`.
#
# **Instructions**:
# - Look above at the mathematical representation $(7)$ of your classifier (section [2.2](#2.2)):
# \begin{align}
# Z^{[1]} &= W^{[1]} X + b^{[1]},\\
# A^{[1]} &= \sigma\left(Z^{[1]}\right),\\
# Z^{[2]} &= W^{[2]} A^{[1]} + b^{[2]},\\
# A^{[2]} &= \sigma\left(Z^{[2]}\right).\\
# \end{align}
# - The steps you have to implement are:
#     1. Retrieve each parameter from the dictionary "parameters" (which is the output of `initialize_parameters()`) by using `parameters[".."]`.
#     2. Implement Forward Propagation. Compute `Z1` multiplying matrices `W1`, `X` and adding vector `b1`. Then find `A1` using the `sigmoid` activation function. Perform similar computations for `Z2` and `A2`.

# %%
# GRADED FUNCTION: forward_propagation

def forward_propagation(X, parameters):
    """
    Argument:
    X -- input data of size (n_x, m)
    parameters -- python dictionary containing your parameters (output of initialization function)
    
    Returns:
    A2 -- the sigmoid output of the second activation
    cache -- python dictionary containing Z1, A1, Z2, A2 
    (that simplifies the calculations in the back propagation step)
    """
    # Retrieve each parameter from the dictionary "parameters".
    ### START CODE HERE ### (~ 4 lines of code)
    W1 = parameters['W1']
    b1 = parameters['b1']
    W2 = parameters['W2']
    b2 = parameters['b2']
    ### END CODE HERE ###
    
    # Implement forward propagation to calculate A2.
    ### START CODE HERE ### (~ 4 lines of code)
    Z1 = W1 @ X + b1
    A1 = sigmoid(Z1)
    Z2 = W2 @ A1 + b2
    A2 = sigmoid(Z2)
    ### END CODE HERE ###
    
    assert(A2.shape == (n_y, X.shape[1]))

    cache = {"Z1": Z1,
             "A1": A1,
             "Z2": Z2,
             "A2": A2}
    
    return A2, cache

# %%
A2, cache = forward_propagation(X, parameters)

print(A2)
# Out:
# [[0.49947316 0.49949226 0.49948616 ... 0.49947033 0.49947412 0.49948389]]

# %% [markdown]
# ##### __Expected Output__
# Note: the elements of the array A2 maybe be different depending on the initial parameters. If you would like to get exactly the same output, try to restart the Kernel and rerun the notebook.
#
# ```Python
# [[0.49920157 0.49922234 0.49921223 ... 0.49921215 0.49921043 0.49920665]]
# ```

# %%
# Note: 
# Actual values are not checked here in the unit tests (due to random initialization).
w3_unittest.test_forward_propagation(forward_propagation)
# Out:
#  All tests passed

# %% [markdown]
# Remember, that your weights were just initialized with some random values, so the model has not been trained yet.

# %% [markdown]
# <a name='ex05'></a>
# ### Exercise 5
#
# Define a cost function $(8)$ which will be used to train the model:
#
# $$\mathcal{L}\left(W, b\right)  = \frac{1}{m}\sum_{i=1}^{m}  \large\left(\small - y^{(i)}\log\left(a^{(i)}\right) - (1-y^{(i)})\log\left(1- a^{(i)}\right)  \large  \right) \small.$$

# %%
def compute_cost(A2, Y):
    """
    Computes the cost function as a log loss
    
    Arguments:
    A2 -- The output of the neural network of shape (1, number of examples)
    Y -- "true" labels vector of shape (1, number of examples)
    
    Returns:
    cost -- log loss
    
    """
    # Number of examples.
    m = Y.shape[1]
    
    ### START CODE HERE ### (~ 2 lines of code)
    logloss = -Y * np.log(A2) - (1 - Y) * np.log(1 - A2)
    cost = np.sum(logloss) / m
    ### END CODE HERE ###

    assert(isinstance(cost, float))
    
    return cost

# %%
print("cost = " + str(compute_cost(A2, Y)))
# Out:
# cost = 0.6931475357408063

# %% [markdown]
# ##### __Expected Output__
# Note: the elements of the arrays W1 and W2 maybe be different!
#
# ```Python
# cost = 0.6931477703826823
# ```

# %%
# Note: 
# Actual values are not checked here in the unit tests (due to random initialization).
w3_unittest.test_compute_cost(compute_cost, A2)
# Out:
#  All tests passed

# %% [markdown]
# Calculate partial derivatives as shown in $(15)$:
#
# \begin{align}
# \frac{\partial \mathcal{L} }{ \partial W^{[2]} } &=
# \frac{1}{m}\left(A^{[2]}-Y\right)\left(A^{[1]}\right)^T,\\
# \frac{\partial \mathcal{L} }{ \partial b^{[2]} } &=
# \frac{1}{m}\left(A^{[2]}-Y\right)\mathbf{1},\\
# \frac{\partial \mathcal{L} }{ \partial W^{[1]}} &= \frac{1}{m}\left(\left(W^{[2]}\right)^T \left(A^{[2]} - Y\right)\cdot \left(A^{[1]}\cdot\left(1-A^{[1]}\right)\right)\right)X^T,\\
# \frac{\partial \mathcal{L} }{ \partial b^{[1]}} &= \frac{1}{m}\left(\left(W^{[2]}\right)^T \left(A^{[2]} - Y\right)\cdot \left(A^{[1]}\cdot\left(1-A^{[1]}\right)\right)\right)\mathbf{1}.\\
# \end{align}

# %%
def backward_propagation(parameters, cache, X, Y):
    """
    Implements the backward propagation, calculating gradients
    
    Arguments:
    parameters -- python dictionary containing our parameters 
    cache -- python dictionary containing Z1, A1, Z2, A2
    X -- input data of shape (n_x, number of examples)
    Y -- "true" labels vector of shape (n_y, number of examples)
    
    Returns:
    grads -- python dictionary containing gradients with respect to different parameters
    """
    m = X.shape[1]
    
    # First, retrieve W from the dictionary "parameters".
    W1 = parameters["W1"]
    W2 = parameters["W2"]
    
    # Retrieve also A1 and A2 from dictionary "cache".
    A1 = cache["A1"]
    A2 = cache["A2"]
    
    # Backward propagation: calculate partial derivatives denoted as dW1, db1, dW2, db2 for simplicity. 
    dZ2 = A2 - Y
    dW2 = 1/m * np.dot(dZ2, A1.T)
    db2 = 1/m * np.sum(dZ2, axis = 1, keepdims = True)
    dZ1 = np.dot(W2.T, dZ2) * A1 * (1 - A1)
    dW1 = 1/m * np.dot(dZ1, X.T)
    db1 = 1/m * np.sum(dZ1, axis = 1, keepdims = True)
    
    grads = {"dW1": dW1,
             "db1": db1,
             "dW2": dW2,
             "db2": db2}
    
    return grads

grads = backward_propagation(parameters, cache, X, Y)

print("dW1 = " + str(grads["dW1"]))
print("db1 = " + str(grads["db1"]))
print("dW2 = " + str(grads["dW2"]))
print("db2 = " + str(grads["db2"]))
# Out:
# dW1 = [[-7.56054712e-05  8.48587435e-05]
#  [ 5.05322772e-05 -5.72665231e-05]]
# db1 = [[ 1.68002224e-06]
#  [-1.14292837e-06]]
# dW2 = [[-0.0002246  -0.00023206]]
# db2 = [[-0.000521]]

# %% [markdown]
# <a name='ex06'></a>
# ### Exercise 6
#
# Implement `update_parameters()`.
#
# **Instructions**:
# - Update parameters as shown in $(9)$ (section [2.3](#2.3)):
# \begin{align}
# W^{[1]} &= W^{[1]} - \alpha \frac{\partial \mathcal{L} }{ \partial W^{[1]} },\\
# b^{[1]} &= b^{[1]} - \alpha \frac{\partial \mathcal{L} }{ \partial b^{[1]} },\\
# W^{[2]} &= W^{[2]} - \alpha \frac{\partial \mathcal{L} }{ \partial W^{[2]} },\\
# b^{[2]} &= b^{[2]} - \alpha \frac{\partial \mathcal{L} }{ \partial b^{[2]} }.\\
# \end{align}
# - The steps you have to implement are:
#     1. Retrieve each parameter from the dictionary "parameters" (which is the output of `initialize_parameters()`) by using `parameters[".."]`.
#     2. Retrieve each derivative from the dictionary "grads" (which is the output of `backward_propagation()`) by using `grads[".."]`.
#     3. Update parameters.

# %%
def update_parameters(parameters, grads, learning_rate=1.2):
    """
    Updates parameters using the gradient descent update rule
    
    Arguments:
    parameters -- python dictionary containing parameters 
    grads -- python dictionary containing gradients
    learning_rate -- learning rate for gradient descent
    
    Returns:
    parameters -- python dictionary containing updated parameters 
    """
    # Retrieve each parameter from the dictionary "parameters".
    ### START CODE HERE ### (~ 4 lines of code)
    W1 = parameters['W1']
    b1 = parameters['b1']
    W2 = parameters['W2']
    b2 = parameters['b2']
    ### END CODE HERE ###
    
    # Retrieve each gradient from the dictionary "grads".
    ### START CODE HERE ### (~ 4 lines of code)
    dW1 = grads['dW1']
    db1 = grads['db1']
    dW2 = grads['dW2']
    db2 = grads['db2']
    ### END CODE HERE ###
    
    # Update rule for each parameter.
    ### START CODE HERE ### (~ 4 lines of code)
    W1 = W1 - learning_rate * dW1
    b1 = b1 - learning_rate * db1
    W2 = W2 - learning_rate * dW2
    b2 = b2 - learning_rate * db2
    ### END CODE HERE ###
    
    parameters = {"W1": W1,
                  "b1": b1,
                  "W2": W2,
                  "b2": b2}
    
    return parameters

# %%
parameters_updated = update_parameters(parameters, grads)

print("W1 updated = " + str(parameters_updated["W1"]))
print("b1 updated = " + str(parameters_updated["b1"]))
print("W2 updated = " + str(parameters_updated["W2"]))
print("b2 updated = " + str(parameters_updated["b2"]))
# Out:
# W1 updated = [[-0.00073669 -0.00637184]
#  [-0.00049882 -0.00470346]]
# b1 updated = [[-2.01602668e-06]
#  [ 1.37151404e-06]]
# W2 updated = [[-0.01286912  0.00912469]]
# b2 updated = [[0.0006252]]

# %% [markdown]
# ##### __Expected Output__
# Note: the actual values can be different!
#
# ```Python
# W1 updated = [[ 0.01790427  0.00434496]
#  [ 0.00099046 -0.01866419]]
# b1 updated = [[-6.13449205e-07]
#  [-8.47483463e-07]]
# W2 updated = [[-0.00238219 -0.00323487]]
# b2 updated = [[0.00094478]]
# ```

# %%
w3_unittest.test_update_parameters(update_parameters)
# Out:
#  All tests passed

# %% [markdown]
# <a name='3.4'></a>
# ### 3.4 - Integrate parts 3.1, 3.2 and 3.3 in nn_model()

# %% [markdown]
# <a name='ex07'></a>
# ### Exercise 7
#
# Build your neural network model in `nn_model()`.
#
# **Instructions**: The neural network model has to use the previous functions in the right order.

# %%
# GRADED FUNCTION: nn_model

def nn_model(X, Y, n_h, num_iterations=10, learning_rate=1.2, print_cost=False):
    """
    Arguments:
    X -- dataset of shape (n_x, number of examples)
    Y -- labels of shape (n_y, number of examples)
    num_iterations -- number of iterations in the loop
    learning_rate -- learning rate parameter for gradient descent
    print_cost -- if True, print the cost every iteration
    
    Returns:
    parameters -- parameters learnt by the model. They can then be used to predict.
    """
    
    n_x = layer_sizes(X, Y)[0]
    n_y = layer_sizes(X, Y)[2]
    
    # Initialize parameters.
    ### START CODE HERE ### (~ 1 line of code)
    parameters = initialize_parameters(n_x, n_h, n_y)
    ### END CODE HERE ###
    
    # Loop.
    for i in range(0, num_iterations):
         
        ### START CODE HERE ### (~ 4 lines of code)
        # Forward propagation. Inputs: "X, parameters". Outputs: "A2, cache".
        A2, cache = forward_propagation(X, parameters)
        
        # Cost function. Inputs: "A2, Y". Outputs: "cost".
        cost = compute_cost(A2, Y)
        
        # Backpropagation. Inputs: "parameters, cache, X, Y". Outputs: "grads".
        grads = backward_propagation(parameters, cache, X, Y)
        
        # Gradient descent parameter update. Inputs: "parameters, grads, learning_rate". Outputs: "parameters".
        parameters = update_parameters(parameters, grads)
        ### END CODE HERE ###
        
        # Print the cost every iteration.
        if print_cost:
            print ("Cost after iteration %i: %f" %(i, cost))

    return parameters

# %%
parameters = nn_model(X, Y, n_h=2, num_iterations=3000, learning_rate=1.2, print_cost=True)
print("W1 = " + str(parameters["W1"]))
print("b1 = " + str(parameters["b1"]))
print("W2 = " + str(parameters["W2"]))
print("b2 = " + str(parameters["b2"]))

W1 = parameters["W1"]
b1 = parameters["b1"]
W2 = parameters["W2"]
b2 = parameters["b2"]
# Out:
# Cost after iteration 0: 0.693153
# Cost after iteration 1: 0.693148
# Cost after iteration 2: 0.693146
# Cost after iteration 3: 0.693146
# Cost after iteration 4: 0.693146
# Cost after iteration 5: 0.693146
# Cost after iteration 6: 0.693146
# Cost after iteration 7: 0.693145
# Cost after iteration 8: 0.693145
# Cost after iteration 9: 0.693145
# Cost after iteration 10: 0.693145
# Cost after iteration 11: 0.693145
# Cost after iteration 12: 0.693145
# Cost after iteration 13: 0.693145
# Cost after iteration 14: 0.693145
# Cost after iteration 15: 0.693145
# Cost after iteration 16: 0.693145
# Cost after iteration 17: 0.693145
# Cost after iteration 18: 0.693145
# Cost after iteration 19: 0.693145
# Cost after iteration 20: 0.693145
# Cost after iteration 21: 0.693145
# Cost after iteration 22: 0.693145
# Cost after iteration 23: 0.693145
# Cost after iteration 24: 0.693145
# Cost after iteration 25: 0.693145
# Cost after iteration 26: 0.693145
# Cost after iteration 27: 0.693145
# Cost after iteration 28: 0.693144
# Cost after iteration 29: 0.693144
# Cost after iteration 30: 0.693144
# Cost after iteration 31: 0.693144
# Cost after iteration 32: 0.693144
# Cost after iteration 33: 0.693144
# Cost after iteration 34: 0.693144
# Cost after iteration 35: 0.693144
# Cost after iteration 36: 0.693144
# Cost after iteration 37: 0.693144
# Cost after iteration 38: 0.693144
# Cost after iteration 39: 0.693144
# Cost after iteration 40: 0.693144
# Cost after iteration 41: 0.693144
# Cost after iteration 42: 0.693144
# Cost after iteration 43: 0.693144
# Cost after iteration 44: 0.693143
# Cost after iteration 45: 0.693143
# Cost after iteration 46: 0.693143
# Cost after iteration 47: 0.693143
# Cost after iteration 48: 0.693143
# Cost after iteration 49: 0.693143
# Cost after iteration 50: 0.693143
# Cost after iteration 51: 0.693143
# Cost after iteration 52: 0.693143
# Cost after iteration 53: 0.693143
# Cost after iteration 54: 0.693143
# Cost after iteration 55: 0.693143
# Cost after iteration 56: 0.693143
# Cost after iteration 57: 0.693142
# Cost after iteration 58: 0.693142
# Cost after iteration 59: 0.693142
# Cost after iteration 60: 0.693142
# Cost after iteration 61: 0.693142
# Cost after iteration 62: 0.693142
# Cost after iteration 63: 0.693142
# Cost after iteration 64: 0.693142
# Cost after iteration 65: 0.693142
# Cost after iteration 66: 0.693142
# Cost after iteration 67: 0.693141
# Cost after iteration 68: 0.693141
# Cost after iteration 69: 0.693141
# Cost after iteration 70: 0.693141
# Cost after iteration 71: 0.693141
# Cost after iteration 72: 0.693141
# Cost after iteration 73: 0.693141
# Cost after iteration 74: 0.693141
# Cost after iteration 75: 0.693141
# Cost after iteration 76: 0.693140
# Cost after iteration 77: 0.693140
# Cost after iteration 78: 0.693140
# Cost after iteration 79: 0.693140
# Cost after iteration 80: 0.693140
# Cost after iteration 81: 0.693140
# Cost after iteration 82: 0.693140
# Cost after iteration 83: 0.693139
# Cost after iteration 84: 0.693139
# Cost after iteration 85: 0.693139
# Cost after iteration 86: 0.693139
# Cost after iteration 87: 0.693139
# Cost after iteration 88: 0.693139
# Cost after iteration 89: 0.693139
# Cost after iteration 90: 0.693138
# Cost after iteration 91: 0.693138
# Cost after iteration 92: 0.693138
# Cost after iteration 93: 0.693138
# Cost after iteration 94: 0.693138
# Cost after iteration 95: 0.693137
# Cost after iteration 96: 0.693137
# Cost after iteration 97: 0.693137
# Cost after iteration 98: 0.693137
# Cost after iteration 99: 0.693137
# Cost after iteration 100: 0.693137
# Cost after iteration 101: 0.693136
# Cost after iteration 102: 0.693136
# Cost after iteration 103: 0.693136
# Cost after iteration 104: 0.693136
# Cost after iteration 105: 0.693135
# Cost after iteration 106: 0.693135
# Cost after iteration 107: 0.693135
# Cost after iteration 108: 0.693135
# Cost after iteration 109: 0.693135
# Cost after iteration 110: 0.693134
# Cost after iteration 111: 0.693134
# Cost after iteration 112: 0.693134
# Cost after iteration 113: 0.693133
# Cost after iteration 114: 0.693133
# Cost after iteration 115: 0.693133
# Cost after iteration 116: 0.693133
# Cost after iteration 117: 0.693132
# Cost after iteration 118: 0.693132
# Cost after iteration 119: 0.693132
# Cost after iteration 120: 0.693131
# Cost after iteration 121: 0.693131
# Cost after iteration 122: 0.693131
# Cost after iteration 123: 0.693130
# Cost after iteration 124: 0.693130
# Cost after iteration 125: 0.693130
# Cost after iteration 126: 0.693129
# Cost after iteration 127: 0.693129
# Cost after iteration 128: 0.693129
# Cost after iteration 129: 0.693128
# Cost after iteration 130: 0.693128
# Cost after iteration 131: 0.693128
# Cost after iteration 132: 0.693127
# Cost after iteration 133: 0.693127
# Cost after iteration 134: 0.693126
# Cost after iteration 135: 0.693126
# Cost after iteration 136: 0.693125
# Cost after iteration 137: 0.693125
# Cost after iteration 138: 0.693124
# Cost after iteration 139: 0.693124
# Cost after iteration 140: 0.693123
# Cost after iteration 141: 0.693123
# Cost after iteration 142: 0.693122
# Cost after iteration 143: 0.693122
# Cost after iteration 144: 0.693121
# Cost after iteration 145: 0.693121
# Cost after iteration 146: 0.693120
# Cost after iteration 147: 0.693119
# Cost after iteration 148: 0.693119
# Cost after iteration 149: 0.693118
# Cost after iteration 150: 0.693117
# Cost after iteration 151: 0.693117
# Cost after iteration 152: 0.693116
# Cost after iteration 153: 0.693115
# Cost after iteration 154: 0.693114
# Cost after iteration 155: 0.693113
# Cost after iteration 156: 0.693113
# Cost after iteration 157: 0.693112
# Cost after iteration 158: 0.693111
# Cost after iteration 159: 0.693110
# Cost after iteration 160: 0.693109
# Cost after iteration 161: 0.693108
# Cost after iteration 162: 0.693107
# Cost after iteration 163: 0.693106
# Cost after iteration 164: 0.693104
# Cost after iteration 165: 0.693103
# Cost after iteration 166: 0.693102
# Cost after iteration 167: 0.693101
# Cost after iteration 168: 0.693099
# Cost after iteration 169: 0.693098
# Cost after iteration 170: 0.693097
# Cost after iteration 171: 0.693095
# Cost after iteration 172: 0.693093
# Cost after iteration 173: 0.693092
# Cost after iteration 174: 0.693090
# Cost after iteration 175: 0.693088
# Cost after iteration 176: 0.693086
# Cost after iteration 177: 0.693084
# Cost after iteration 178: 0.693082
# Cost after iteration 179: 0.693080
# Cost after iteration 180: 0.693078
# Cost after iteration 181: 0.693075
# Cost after iteration 182: 0.693073
# Cost after iteration 183: 0.693070
# Cost after iteration 184: 0.693067
# Cost after iteration 185: 0.693064
# Cost after iteration 186: 0.693061
# Cost after iteration 187: 0.693057
# Cost after iteration 188: 0.693054
# Cost after iteration 189: 0.693050
# Cost after iteration 190: 0.693046
# Cost after iteration 191: 0.693041
# Cost after iteration 192: 0.693037
# Cost after iteration 193: 0.693032
# Cost after iteration 194: 0.693027
# Cost after iteration 195: 0.693021
# Cost after iteration 196: 0.693015
# Cost after iteration 197: 0.693009
# Cost after iteration 198: 0.693002
# Cost after iteration 199: 0.692994
# Cost after iteration 200: 0.692986
# Cost after iteration 201: 0.692977
# Cost after iteration 202: 0.692968
# Cost after iteration 203: 0.692958
# Cost after iteration 204: 0.692947
# Cost after iteration 205: 0.692935
# Cost after iteration 206: 0.692922
# Cost after iteration 207: 0.692908
# Cost after iteration 208: 0.692892
# Cost after iteration 209: 0.692875
# Cost after iteration 210: 0.692856
# Cost after iteration 211: 0.692835
# Cost after iteration 212: 0.692812
# Cost after iteration 213: 0.692787
# Cost after iteration 214: 0.692759
# Cost after iteration 215: 0.692727
# Cost after iteration 216: 0.692692
# Cost after iteration 217: 0.692653
# Cost after iteration 218: 0.692609
# Cost after iteration 219: 0.692560
# Cost after iteration 220: 0.692504
# Cost after iteration 221: 0.692441
# Cost after iteration 222: 0.692369
# Cost after iteration 223: 0.692288
# Cost after iteration 224: 0.692195
# Cost after iteration 225: 0.692089
# Cost after iteration 226: 0.691968
# Cost after iteration 227: 0.691828
# Cost after iteration 228: 0.691668
# Cost after iteration 229: 0.691483
# Cost after iteration 230: 0.691269
# Cost after iteration 231: 0.691023
# Cost after iteration 232: 0.690738
# Cost after iteration 233: 0.690409
# Cost after iteration 234: 0.690030
# Cost after iteration 235: 0.689592
# Cost after iteration 236: 0.689088
# Cost after iteration 237: 0.688510
# Cost after iteration 238: 0.687849
# Cost after iteration 239: 0.687096
# Cost after iteration 240: 0.686244
# Cost after iteration 241: 0.685283
# Cost after iteration 242: 0.684208
# Cost after iteration 243: 0.683014
# Cost after iteration 244: 0.681695
# Cost after iteration 245: 0.680252
# Cost after iteration 246: 0.678684
# Cost after iteration 247: 0.676993
# Cost after iteration 248: 0.675185
# Cost after iteration 249: 0.673264
# Cost after iteration 250: 0.671239
# Cost after iteration 251: 0.669115
# Cost after iteration 252: 0.666902
# Cost after iteration 253: 0.664607
# Cost after iteration 254: 0.662238
# Cost after iteration 255: 0.659801
# Cost after iteration 256: 0.657303
# Cost after iteration 257: 0.654749
# Cost after iteration 258: 0.652148
# Cost after iteration 259: 0.649505
# Cost after iteration 260: 0.646832
# Cost after iteration 261: 0.644140
# Cost after iteration 262: 0.641443
# Cost after iteration 263: 0.638758
# Cost after iteration 264: 0.636100
# Cost after iteration 265: 0.633485
# Cost after iteration 266: 0.630923
# Cost after iteration 267: 0.628424
# Cost after iteration 268: 0.625993
# Cost after iteration 269: 0.623633
# Cost after iteration 270: 0.621347
# Cost after iteration 271: 0.619133
# Cost after iteration 272: 0.616990
# Cost after iteration 273: 0.614916
# Cost after iteration 274: 0.612910
# Cost after iteration 275: 0.610968
# Cost after iteration 276: 0.609088
# Cost after iteration 277: 0.607268
# Cost after iteration 278: 0.605503
# Cost after iteration 279: 0.603792
# Cost after iteration 280: 0.602133
# Cost after iteration 281: 0.600521
# Cost after iteration 282: 0.598955
# Cost after iteration 283: 0.597432
# Cost after iteration 284: 0.595951
# Cost after iteration 285: 0.594508
# Cost after iteration 286: 0.593102
# Cost after iteration 287: 0.591730
# Cost after iteration 288: 0.590391
# Cost after iteration 289: 0.589082
# Cost after iteration 290: 0.587803
# Cost after iteration 291: 0.586551
# Cost after iteration 292: 0.585324
# Cost after iteration 293: 0.584122
# Cost after iteration 294: 0.582943
# Cost after iteration 295: 0.581785
# Cost after iteration 296: 0.580647
# Cost after iteration 297: 0.579528
# Cost after iteration 298: 0.578427
# Cost after iteration 299: 0.577343
# Cost after iteration 300: 0.576274
# Cost after iteration 301: 0.575220
# Cost after iteration 302: 0.574179
# Cost after iteration 303: 0.573152
# Cost after iteration 304: 0.572136
# Cost after iteration 305: 0.571131
# Cost after iteration 306: 0.570137
# Cost after iteration 307: 0.569151
# Cost after iteration 308: 0.568175
# Cost after iteration 309: 0.567207
# Cost after iteration 310: 0.566246
# Cost after iteration 311: 0.565292
# Cost after iteration 312: 0.564344
# Cost after iteration 313: 0.563401
# Cost after iteration 314: 0.562464
# Cost after iteration 315: 0.561531
# Cost after iteration 316: 0.560601
# Cost after iteration 317: 0.559676
# Cost after iteration 318: 0.558753
# Cost after iteration 319: 0.557833
# Cost after iteration 320: 0.556915
# Cost after iteration 321: 0.555999
# Cost after iteration 322: 0.555084
# Cost after iteration 323: 0.554169
# Cost after iteration 324: 0.553255
# Cost after iteration 325: 0.552341
# Cost after iteration 326: 0.551427
# Cost after iteration 327: 0.550511
# Cost after iteration 328: 0.549594
# Cost after iteration 329: 0.548675
# Cost after iteration 330: 0.547753
# Cost after iteration 331: 0.546827
# Cost after iteration 332: 0.545896
# Cost after iteration 333: 0.544959
# Cost after iteration 334: 0.544012
# Cost after iteration 335: 0.543054
# Cost after iteration 336: 0.542079
# Cost after iteration 337: 0.541080
# Cost after iteration 338: 0.540042
# Cost after iteration 339: 0.538942
# Cost after iteration 340: 0.537731
# Cost after iteration 341: 0.536302
# Cost after iteration 342: 0.534396
# Cost after iteration 343: 0.531313
# Cost after iteration 344: 0.525186
# Cost after iteration 345: 0.512744
# Cost after iteration 346: 0.492837
# Cost after iteration 347: 0.471364
# Cost after iteration 348: 0.460167
# Cost after iteration 349: 0.510326
# Cost after iteration 350: 0.617879
# Cost after iteration 351: 0.516124
# Cost after iteration 352: 0.518783
# Cost after iteration 353: 0.498240
# Cost after iteration 354: 0.439718
# Cost after iteration 355: 0.428375
# Cost after iteration 356: 0.403525
# Cost after iteration 357: 0.392611
# Cost after iteration 358: 0.382134
# Cost after iteration 359: 0.375651
# Cost after iteration 360: 0.370390
# Cost after iteration 361: 0.366154
# Cost after iteration 362: 0.362393
# Cost after iteration 363: 0.358950
# Cost after iteration 364: 0.355707
# Cost after iteration 365: 0.352617
# Cost after iteration 366: 0.349651
# Cost after iteration 367: 0.346792
# Cost after iteration 368: 0.344030
# Cost after iteration 369: 0.341360
# Cost after iteration 370: 0.338774
# Cost after iteration 371: 0.336269
# Cost after iteration 372: 0.333840
# Cost after iteration 373: 0.331484
# Cost after iteration 374: 0.329198
# Cost after iteration 375: 0.326977
# Cost after iteration 376: 0.324820
# Cost after iteration 377: 0.322723
# Cost after iteration 378: 0.320684
# Cost after iteration 379: 0.318700
# Cost after iteration 380: 0.316768
# Cost after iteration 381: 0.314887
# Cost after iteration 382: 0.313054
# Cost after iteration 383: 0.311267
# Cost after iteration 384: 0.309524
# Cost after iteration 385: 0.307824
# Cost after iteration 386: 0.306164
# Cost after iteration 387: 0.304543
# Cost after iteration 388: 0.302959
# Cost after iteration 389: 0.301411
# Cost after iteration 390: 0.299897
# Cost after iteration 391: 0.298417
# Cost after iteration 392: 0.296968
# Cost after iteration 393: 0.295549
# Cost after iteration 394: 0.294160
# Cost after iteration 395: 0.292799
# Cost after iteration 396: 0.291465
# Cost after iteration 397: 0.290157
# Cost after iteration 398: 0.288875
# Cost after iteration 399: 0.287616
# Cost after iteration 400: 0.286381
# Cost after iteration 401: 0.285168
# Cost after iteration 402: 0.283978
# Cost after iteration 403: 0.282808
# Cost after iteration 404: 0.281658
# Cost after iteration 405: 0.280527
# Cost after iteration 406: 0.279416
# Cost after iteration 407: 0.278323
# Cost after iteration 408: 0.277247
# Cost after iteration 409: 0.276188
# Cost after iteration 410: 0.275146
# Cost after iteration 411: 0.274120
# Cost after iteration 412: 0.273109
# Cost after iteration 413: 0.272114
# Cost after iteration 414: 0.271132
# Cost after iteration 415: 0.270165
# Cost after iteration 416: 0.269212
# Cost after iteration 417: 0.268271
# Cost after iteration 418: 0.267344
# Cost after iteration 419: 0.266429
# Cost after iteration 420: 0.265526
# Cost after iteration 421: 0.264635
# Cost after iteration 422: 0.263756
# Cost after iteration 423: 0.262887
# Cost after iteration 424: 0.262030
# Cost after iteration 425: 0.261183
# Cost after iteration 426: 0.260346
# Cost after iteration 427: 0.259520
# Cost after iteration 428: 0.258703
# Cost after iteration 429: 0.257896
# Cost after iteration 430: 0.257099
# Cost after iteration 431: 0.256310
# Cost after iteration 432: 0.255531
# Cost after iteration 433: 0.254760
# Cost after iteration 434: 0.253998
# Cost after iteration 435: 0.253244
# Cost after iteration 436: 0.252499
# Cost after iteration 437: 0.251761
# Cost after iteration 438: 0.251032
# Cost after iteration 439: 0.250310
# Cost after iteration 440: 0.249596
# Cost after iteration 441: 0.248889
# Cost after iteration 442: 0.248190
# Cost after iteration 443: 0.247498
# Cost after iteration 444: 0.246813
# Cost after iteration 445: 0.246136
# Cost after iteration 446: 0.245465
# Cost after iteration 447: 0.244801
# Cost after iteration 448: 0.244144
# Cost after iteration 449: 0.243493
# Cost after iteration 450: 0.242849
# Cost after iteration 451: 0.242211
# Cost after iteration 452: 0.241580
# Cost after iteration 453: 0.240955
# Cost after iteration 454: 0.240337
# Cost after iteration 455: 0.239724
# Cost after iteration 456: 0.239118
# Cost after iteration 457: 0.238518
# Cost after iteration 458: 0.237923
# Cost after iteration 459: 0.237335
# Cost after iteration 460: 0.236752
# Cost after iteration 461: 0.236176
# Cost after iteration 462: 0.235605
# Cost after iteration 463: 0.235040
# Cost after iteration 464: 0.234481
# Cost after iteration 465: 0.233929
# Cost after iteration 466: 0.233385
# Cost after iteration 467: 0.232854
# Cost after iteration 468: 0.232349
# Cost after iteration 469: 0.231904
# Cost after iteration 470: 0.231617
# Cost after iteration 471: 0.231762
# Cost after iteration 472: 0.233167
# Cost after iteration 473: 0.238263
# Cost after iteration 474: 0.255409
# Cost after iteration 475: 0.313182
# Cost after iteration 476: 0.475903
# Cost after iteration 477: 0.740773
# Cost after iteration 478: 0.243348
# Cost after iteration 479: 0.238473
# Cost after iteration 480: 0.235467
# Cost after iteration 481: 0.233752
# Cost after iteration 482: 0.232596
# Cost after iteration 483: 0.231647
# Cost after iteration 484: 0.230880
# Cost after iteration 485: 0.230173
# Cost after iteration 486: 0.229540
# Cost after iteration 487: 0.228933
# Cost after iteration 488: 0.228363
# Cost after iteration 489: 0.227808
# Cost after iteration 490: 0.227274
# Cost after iteration 491: 0.226751
# Cost after iteration 492: 0.226242
# Cost after iteration 493: 0.225742
# Cost after iteration 494: 0.225256
# Cost after iteration 495: 0.224777
# Cost after iteration 496: 0.224313
# Cost after iteration 497: 0.223860
# Cost after iteration 498: 0.223428
# Cost after iteration 499: 0.223013
# Cost after iteration 500: 0.222635
# Cost after iteration 501: 0.222294
# Cost after iteration 502: 0.222032
# Cost after iteration 503: 0.221861
# Cost after iteration 504: 0.221896
# Cost after iteration 505: 0.222191
# Cost after iteration 506: 0.223109
# Cost after iteration 507: 0.224892
# Cost after iteration 508: 0.228899
# Cost after iteration 509: 0.236402
# Cost after iteration 510: 0.253032
# Cost after iteration 511: 0.288380
# Cost after iteration 512: 0.350017
# Cost after iteration 513: 0.482918
# Cost after iteration 514: 0.413137
# Cost after iteration 515: 0.427279
# Cost after iteration 516: 0.316770
# Cost after iteration 517: 0.275964
# Cost after iteration 518: 0.246839
# Cost after iteration 519: 0.235563
# Cost after iteration 520: 0.230195
# Cost after iteration 521: 0.228300
# Cost after iteration 522: 0.226112
# Cost after iteration 523: 0.225019
# Cost after iteration 524: 0.223789
# Cost after iteration 525: 0.222996
# Cost after iteration 526: 0.222175
# Cost after iteration 527: 0.221542
# Cost after iteration 528: 0.220909
# Cost after iteration 529: 0.220362
# Cost after iteration 530: 0.219819
# Cost after iteration 531: 0.219320
# Cost after iteration 532: 0.218825
# Cost after iteration 533: 0.218354
# Cost after iteration 534: 0.217886
# Cost after iteration 535: 0.217434
# Cost after iteration 536: 0.216984
# Cost after iteration 537: 0.216545
# Cost after iteration 538: 0.216109
# Cost after iteration 539: 0.215681
# Cost after iteration 540: 0.215256
# Cost after iteration 541: 0.214837
# Cost after iteration 542: 0.214422
# Cost after iteration 543: 0.214013
# Cost after iteration 544: 0.213608
# Cost after iteration 545: 0.213209
# Cost after iteration 546: 0.212814
# Cost after iteration 547: 0.212425
# Cost after iteration 548: 0.212041
# Cost after iteration 549: 0.211664
# Cost after iteration 550: 0.211292
# Cost after iteration 551: 0.210930
# Cost after iteration 552: 0.210573
# Cost after iteration 553: 0.210229
# Cost after iteration 554: 0.209892
# Cost after iteration 555: 0.209575
# Cost after iteration 556: 0.209268
# Cost after iteration 557: 0.208994
# Cost after iteration 558: 0.208738
# Cost after iteration 559: 0.208545
# Cost after iteration 560: 0.208388
# Cost after iteration 561: 0.208364
# Cost after iteration 562: 0.208428
# Cost after iteration 563: 0.208810
# Cost after iteration 564: 0.209437
# Cost after iteration 565: 0.210934
# Cost after iteration 566: 0.213236
# Cost after iteration 567: 0.218329
# Cost after iteration 568: 0.226740
# Cost after iteration 569: 0.246528
# Cost after iteration 570: 0.283570
# Cost after iteration 571: 0.391719
# Cost after iteration 572: 0.509773
# Cost after iteration 573: 0.815143
# Cost after iteration 574: 0.338259
# Cost after iteration 575: 0.340263
# Cost after iteration 576: 0.242277
# Cost after iteration 577: 0.229336
# Cost after iteration 578: 0.219485
# Cost after iteration 579: 0.216291
# Cost after iteration 580: 0.214347
# Cost after iteration 581: 0.213307
# Cost after iteration 582: 0.212545
# Cost after iteration 583: 0.211949
# Cost after iteration 584: 0.211422
# Cost after iteration 585: 0.210938
# Cost after iteration 586: 0.210478
# Cost after iteration 587: 0.210036
# Cost after iteration 588: 0.209607
# Cost after iteration 589: 0.209189
# Cost after iteration 590: 0.208781
# Cost after iteration 591: 0.208381
# Cost after iteration 592: 0.207989
# Cost after iteration 593: 0.207604
# Cost after iteration 594: 0.207225
# Cost after iteration 595: 0.206854
# Cost after iteration 596: 0.206488
# Cost after iteration 597: 0.206129
# Cost after iteration 598: 0.205775
# Cost after iteration 599: 0.205426
# Cost after iteration 600: 0.205084
# Cost after iteration 601: 0.204746
# Cost after iteration 602: 0.204414
# Cost after iteration 603: 0.204087
# Cost after iteration 604: 0.203766
# Cost after iteration 605: 0.203449
# Cost after iteration 606: 0.203138
# Cost after iteration 607: 0.202831
# Cost after iteration 608: 0.202530
# Cost after iteration 609: 0.202234
# Cost after iteration 610: 0.201942
# Cost after iteration 611: 0.201655
# Cost after iteration 612: 0.201374
# Cost after iteration 613: 0.201097
# Cost after iteration 614: 0.200825
# Cost after iteration 615: 0.200557
# Cost after iteration 616: 0.200295
# Cost after iteration 617: 0.200037
# Cost after iteration 618: 0.199784
# Cost after iteration 619: 0.199535
# Cost after iteration 620: 0.199292
# Cost after iteration 621: 0.199053
# Cost after iteration 622: 0.198820
# Cost after iteration 623: 0.198592
# Cost after iteration 624: 0.198372
# Cost after iteration 625: 0.198163
# Cost after iteration 626: 0.197972
# Cost after iteration 627: 0.197815
# Cost after iteration 628: 0.197727
# Cost after iteration 629: 0.197794
# Cost after iteration 630: 0.198203
# Cost after iteration 631: 0.199462
# Cost after iteration 632: 0.202722
# Cost after iteration 633: 0.211723
# Cost after iteration 634: 0.236296
# Cost after iteration 635: 0.319261
# Cost after iteration 636: 0.491423
# Cost after iteration 637: 0.757246
# Cost after iteration 638: 0.266438
# Cost after iteration 639: 0.284748
# Cost after iteration 640: 0.256757
# Cost after iteration 641: 0.271697
# Cost after iteration 642: 0.237989
# Cost after iteration 643: 0.241148
# Cost after iteration 644: 0.222697
# Cost after iteration 645: 0.222105
# Cost after iteration 646: 0.214083
# Cost after iteration 647: 0.212860
# Cost after iteration 648: 0.208887
# Cost after iteration 649: 0.207764
# Cost after iteration 650: 0.205603
# Cost after iteration 651: 0.204733
# Cost after iteration 652: 0.203461
# Cost after iteration 653: 0.202811
# Cost after iteration 654: 0.201991
# Cost after iteration 655: 0.201493
# Cost after iteration 656: 0.200913
# Cost after iteration 657: 0.200517
# Cost after iteration 658: 0.200074
# Cost after iteration 659: 0.199749
# Cost after iteration 660: 0.199395
# Cost after iteration 661: 0.199128
# Cost after iteration 662: 0.198843
# Cost after iteration 663: 0.198635
# Cost after iteration 664: 0.198419
# Cost after iteration 665: 0.198289
# Cost after iteration 666: 0.198167
# Cost after iteration 667: 0.198167
# Cost after iteration 668: 0.198211
# Cost after iteration 669: 0.198473
# Cost after iteration 670: 0.198872
# Cost after iteration 671: 0.199747
# Cost after iteration 672: 0.201038
# Cost after iteration 673: 0.203580
# Cost after iteration 674: 0.207537
# Cost after iteration 675: 0.215564
# Cost after iteration 676: 0.229372
# Cost after iteration 677: 0.261442
# Cost after iteration 678: 0.312117
# Cost after iteration 679: 0.444310
# Cost after iteration 680: 0.451381
# Cost after iteration 681: 0.529532
# Cost after iteration 682: 0.352053
# Cost after iteration 683: 0.344913
# Cost after iteration 684: 0.262838
# Cost after iteration 685: 0.249995
# Cost after iteration 686: 0.222746
# Cost after iteration 687: 0.219469
# Cost after iteration 688: 0.211701
# Cost after iteration 689: 0.209692
# Cost after iteration 690: 0.206654
# Cost after iteration 691: 0.205389
# Cost after iteration 692: 0.204018
# Cost after iteration 693: 0.203239
# Cost after iteration 694: 0.202495
# Cost after iteration 695: 0.201961
# Cost after iteration 696: 0.201461
# Cost after iteration 697: 0.201042
# Cost after iteration 698: 0.200644
# Cost after iteration 699: 0.200283
# Cost after iteration 700: 0.199934
# Cost after iteration 701: 0.199605
# Cost after iteration 702: 0.199285
# Cost after iteration 703: 0.198977
# Cost after iteration 704: 0.198676
# Cost after iteration 705: 0.198383
# Cost after iteration 706: 0.198097
# Cost after iteration 707: 0.197818
# Cost after iteration 708: 0.197544
# Cost after iteration 709: 0.197276
# Cost after iteration 710: 0.197014
# Cost after iteration 711: 0.196758
# Cost after iteration 712: 0.196506
# Cost after iteration 713: 0.196260
# Cost after iteration 714: 0.196019
# Cost after iteration 715: 0.195784
# Cost after iteration 716: 0.195553
# Cost after iteration 717: 0.195328
# Cost after iteration 718: 0.195107
# Cost after iteration 719: 0.194893
# Cost after iteration 720: 0.194683
# Cost after iteration 721: 0.194479
# Cost after iteration 722: 0.194281
# Cost after iteration 723: 0.194090
# Cost after iteration 724: 0.193904
# Cost after iteration 725: 0.193729
# Cost after iteration 726: 0.193560
# Cost after iteration 727: 0.193406
# Cost after iteration 728: 0.193262
# Cost after iteration 729: 0.193143
# Cost after iteration 730: 0.193042
# Cost after iteration 731: 0.192990
# Cost after iteration 732: 0.192970
# Cost after iteration 733: 0.193064
# Cost after iteration 734: 0.193225
# Cost after iteration 735: 0.193671
# Cost after iteration 736: 0.194267
# Cost after iteration 737: 0.195657
# Cost after iteration 738: 0.197394
# Cost after iteration 739: 0.201585
# Cost after iteration 740: 0.206522
# Cost after iteration 741: 0.219716
# Cost after iteration 742: 0.233543
# Cost after iteration 743: 0.277607
# Cost after iteration 744: 0.319032
# Cost after iteration 745: 0.509887
# Cost after iteration 746: 0.559156
# Cost after iteration 747: 0.910688
# Cost after iteration 748: 0.284208
# Cost after iteration 749: 0.255243
# Cost after iteration 750: 0.211952
# Cost after iteration 751: 0.206270
# Cost after iteration 752: 0.203645
# Cost after iteration 753: 0.202503
# Cost after iteration 754: 0.201777
# Cost after iteration 755: 0.201226
# Cost after iteration 756: 0.200743
# Cost after iteration 757: 0.200298
# Cost after iteration 758: 0.199878
# Cost after iteration 759: 0.199477
# Cost after iteration 760: 0.199093
# Cost after iteration 761: 0.198724
# Cost after iteration 762: 0.198368
# Cost after iteration 763: 0.198026
# Cost after iteration 764: 0.197696
# Cost after iteration 765: 0.197377
# Cost after iteration 766: 0.197069
# Cost after iteration 767: 0.196771
# Cost after iteration 768: 0.196482
# Cost after iteration 769: 0.196202
# Cost after iteration 770: 0.195931
# Cost after iteration 771: 0.195668
# Cost after iteration 772: 0.195412
# Cost after iteration 773: 0.195164
# Cost after iteration 774: 0.194922
# Cost after iteration 775: 0.194688
# Cost after iteration 776: 0.194459
# Cost after iteration 777: 0.194237
# Cost after iteration 778: 0.194021
# Cost after iteration 779: 0.193810
# Cost after iteration 780: 0.193605
# Cost after iteration 781: 0.193406
# Cost after iteration 782: 0.193211
# Cost after iteration 783: 0.193021
# Cost after iteration 784: 0.192836
# Cost after iteration 785: 0.192656
# Cost after iteration 786: 0.192481
# Cost after iteration 787: 0.192309
# Cost after iteration 788: 0.192142
# Cost after iteration 789: 0.191980
# Cost after iteration 790: 0.191821
# Cost after iteration 791: 0.191666
# Cost after iteration 792: 0.191515
# Cost after iteration 793: 0.191367
# Cost after iteration 794: 0.191224
# Cost after iteration 795: 0.191083
# Cost after iteration 796: 0.190947
# Cost after iteration 797: 0.190813
# Cost after iteration 798: 0.190683
# Cost after iteration 799: 0.190556
# Cost after iteration 800: 0.190432
# Cost after iteration 801: 0.190311
# Cost after iteration 802: 0.190192
# Cost after iteration 803: 0.190077
# Cost after iteration 804: 0.189964
# Cost after iteration 805: 0.189855
# Cost after iteration 806: 0.189747
# Cost after iteration 807: 0.189642
# Cost after iteration 808: 0.189540
# Cost after iteration 809: 0.189440
# Cost after iteration 810: 0.189343
# Cost after iteration 811: 0.189247
# Cost after iteration 812: 0.189154
# Cost after iteration 813: 0.189063
# Cost after iteration 814: 0.188974
# Cost after iteration 815: 0.188887
# Cost after iteration 816: 0.188802
# Cost after iteration 817: 0.188719
# Cost after iteration 818: 0.188639
# Cost after iteration 819: 0.188560
# Cost after iteration 820: 0.188484
# Cost after iteration 821: 0.188412
# Cost after iteration 822: 0.188346
# Cost after iteration 823: 0.188292
# Cost after iteration 824: 0.188259
# Cost after iteration 825: 0.188275
# Cost after iteration 826: 0.188392
# Cost after iteration 827: 0.188751
# Cost after iteration 828: 0.189627
# Cost after iteration 829: 0.191852
# Cost after iteration 830: 0.196950
# Cost after iteration 831: 0.211292
# Cost after iteration 832: 0.247768
# Cost after iteration 833: 0.387883
# Cost after iteration 834: 0.564143
# Cost after iteration 835: 0.852480
# Cost after iteration 836: 0.305848
# Cost after iteration 837: 0.427342
# Cost after iteration 838: 0.258506
# Cost after iteration 839: 0.260791
# Cost after iteration 840: 0.210811
# Cost after iteration 841: 0.206427
# Cost after iteration 842: 0.200951
# Cost after iteration 843: 0.198972
# Cost after iteration 844: 0.197422
# Cost after iteration 845: 0.196573
# Cost after iteration 846: 0.195922
# Cost after iteration 847: 0.195439
# Cost after iteration 848: 0.195026
# Cost after iteration 849: 0.194667
# Cost after iteration 850: 0.194337
# Cost after iteration 851: 0.194032
# Cost after iteration 852: 0.193744
# Cost after iteration 853: 0.193472
# Cost after iteration 854: 0.193212
# Cost after iteration 855: 0.192965
# Cost after iteration 856: 0.192728
# Cost after iteration 857: 0.192501
# Cost after iteration 858: 0.192283
# Cost after iteration 859: 0.192074
# Cost after iteration 860: 0.191872
# Cost after iteration 861: 0.191678
# Cost after iteration 862: 0.191492
# Cost after iteration 863: 0.191312
# Cost after iteration 864: 0.191138
# Cost after iteration 865: 0.190971
# Cost after iteration 866: 0.190809
# Cost after iteration 867: 0.190653
# Cost after iteration 868: 0.190502
# Cost after iteration 869: 0.190355
# Cost after iteration 870: 0.190214
# Cost after iteration 871: 0.190077
# Cost after iteration 872: 0.189944
# Cost after iteration 873: 0.189816
# Cost after iteration 874: 0.189691
# Cost after iteration 875: 0.189570
# Cost after iteration 876: 0.189453
# Cost after iteration 877: 0.189340
# Cost after iteration 878: 0.189229
# Cost after iteration 879: 0.189122
# Cost after iteration 880: 0.189018
# Cost after iteration 881: 0.188917
# Cost after iteration 882: 0.188819
# Cost after iteration 883: 0.188724
# Cost after iteration 884: 0.188632
# Cost after iteration 885: 0.188544
# Cost after iteration 886: 0.188458
# Cost after iteration 887: 0.188376
# Cost after iteration 888: 0.188299
# Cost after iteration 889: 0.188227
# Cost after iteration 890: 0.188163
# Cost after iteration 891: 0.188111
# Cost after iteration 892: 0.188077
# Cost after iteration 893: 0.188073
# Cost after iteration 894: 0.188116
# Cost after iteration 895: 0.188250
# Cost after iteration 896: 0.188523
# Cost after iteration 897: 0.189095
# Cost after iteration 898: 0.190110
# Cost after iteration 899: 0.192219
# Cost after iteration 900: 0.195877
# Cost after iteration 901: 0.204274
# Cost after iteration 902: 0.219581
# Cost after iteration 903: 0.265238
# Cost after iteration 904: 0.345005
# Cost after iteration 905: 0.565422
# Cost after iteration 906: 0.457841
# Cost after iteration 907: 0.642405
# Cost after iteration 908: 0.390590
# Cost after iteration 909: 0.438434
# Cost after iteration 910: 0.255073
# Cost after iteration 911: 0.231120
# Cost after iteration 912: 0.208054
# Cost after iteration 913: 0.202760
# Cost after iteration 914: 0.199417
# Cost after iteration 915: 0.198079
# Cost after iteration 916: 0.197224
# Cost after iteration 917: 0.196681
# Cost after iteration 918: 0.196246
# Cost after iteration 919: 0.195875
# Cost after iteration 920: 0.195536
# Cost after iteration 921: 0.195218
# Cost after iteration 922: 0.194916
# Cost after iteration 923: 0.194628
# Cost after iteration 924: 0.194350
# Cost after iteration 925: 0.194084
# Cost after iteration 926: 0.193828
# Cost after iteration 927: 0.193580
# Cost after iteration 928: 0.193342
# Cost after iteration 929: 0.193111
# Cost after iteration 930: 0.192889
# Cost after iteration 931: 0.192674
# Cost after iteration 932: 0.192466
# Cost after iteration 933: 0.192265
# Cost after iteration 934: 0.192070
# Cost after iteration 935: 0.191882
# Cost after iteration 936: 0.191699
# Cost after iteration 937: 0.191523
# Cost after iteration 938: 0.191351
# Cost after iteration 939: 0.191185
# Cost after iteration 940: 0.191024
# Cost after iteration 941: 0.190868
# Cost after iteration 942: 0.190716
# Cost after iteration 943: 0.190569
# Cost after iteration 944: 0.190425
# Cost after iteration 945: 0.190287
# Cost after iteration 946: 0.190152
# Cost after iteration 947: 0.190020
# Cost after iteration 948: 0.189893
# Cost after iteration 949: 0.189769
# Cost after iteration 950: 0.189649
# Cost after iteration 951: 0.189532
# Cost after iteration 952: 0.189418
# Cost after iteration 953: 0.189307
# Cost after iteration 954: 0.189199
# Cost after iteration 955: 0.189095
# Cost after iteration 956: 0.188993
# Cost after iteration 957: 0.188893
# Cost after iteration 958: 0.188797
# Cost after iteration 959: 0.188703
# Cost after iteration 960: 0.188611
# Cost after iteration 961: 0.188522
# Cost after iteration 962: 0.188435
# Cost after iteration 963: 0.188350
# Cost after iteration 964: 0.188268
# Cost after iteration 965: 0.188188
# Cost after iteration 966: 0.188109
# Cost after iteration 967: 0.188033
# Cost after iteration 968: 0.187959
# Cost after iteration 969: 0.187886
# Cost after iteration 970: 0.187816
# Cost after iteration 971: 0.187747
# Cost after iteration 972: 0.187680
# Cost after iteration 973: 0.187614
# Cost after iteration 974: 0.187550
# Cost after iteration 975: 0.187488
# Cost after iteration 976: 0.187427
# Cost after iteration 977: 0.187367
# Cost after iteration 978: 0.187309
# Cost after iteration 979: 0.187253
# Cost after iteration 980: 0.187197
# Cost after iteration 981: 0.187143
# Cost after iteration 982: 0.187091
# Cost after iteration 983: 0.187040
# Cost after iteration 984: 0.186990
# Cost after iteration 985: 0.186942
# Cost after iteration 986: 0.186896
# Cost after iteration 987: 0.186852
# Cost after iteration 988: 0.186813
# Cost after iteration 989: 0.186779
# Cost after iteration 990: 0.186755
# Cost after iteration 991: 0.186748
# Cost after iteration 992: 0.186769
# Cost after iteration 993: 0.186848
# Cost after iteration 994: 0.187019
# Cost after iteration 995: 0.187400
# Cost after iteration 996: 0.188087
# Cost after iteration 997: 0.189611
# Cost after iteration 998: 0.192196
# Cost after iteration 999: 0.198508
# Cost after iteration 1000: 0.208675
# Cost after iteration 1001: 0.237639
# Cost after iteration 1002: 0.276921
# Cost after iteration 1003: 0.437120
# Cost after iteration 1004: 0.558646
# Cost after iteration 1005: 1.297682
# Cost after iteration 1006: 0.224139
# Cost after iteration 1007: 0.209489
# Cost after iteration 1008: 0.200883
# Cost after iteration 1009: 0.198994
# Cost after iteration 1010: 0.198045
# Cost after iteration 1011: 0.197379
# Cost after iteration 1012: 0.196803
# Cost after iteration 1013: 0.196276
# Cost after iteration 1014: 0.195784
# Cost after iteration 1015: 0.195323
# Cost after iteration 1016: 0.194891
# Cost after iteration 1017: 0.194484
# Cost after iteration 1018: 0.194101
# Cost after iteration 1019: 0.193741
# Cost after iteration 1020: 0.193401
# Cost after iteration 1021: 0.193081
# Cost after iteration 1022: 0.192778
# Cost after iteration 1023: 0.192492
# Cost after iteration 1024: 0.192222
# Cost after iteration 1025: 0.191966
# Cost after iteration 1026: 0.191723
# Cost after iteration 1027: 0.191493
# Cost after iteration 1028: 0.191275
# Cost after iteration 1029: 0.191068
# Cost after iteration 1030: 0.190871
# Cost after iteration 1031: 0.190684
# Cost after iteration 1032: 0.190505
# Cost after iteration 1033: 0.190335
# Cost after iteration 1034: 0.190173
# Cost after iteration 1035: 0.190018
# Cost after iteration 1036: 0.189870
# Cost after iteration 1037: 0.189728
# Cost after iteration 1038: 0.189593
# Cost after iteration 1039: 0.189463
# Cost after iteration 1040: 0.189338
# Cost after iteration 1041: 0.189219
# Cost after iteration 1042: 0.189104
# Cost after iteration 1043: 0.188994
# Cost after iteration 1044: 0.188888
# Cost after iteration 1045: 0.188785
# Cost after iteration 1046: 0.188687
# Cost after iteration 1047: 0.188592
# Cost after iteration 1048: 0.188500
# Cost after iteration 1049: 0.188411
# Cost after iteration 1050: 0.188326
# Cost after iteration 1051: 0.188243
# Cost after iteration 1052: 0.188163
# Cost after iteration 1053: 0.188085
# Cost after iteration 1054: 0.188010
# Cost after iteration 1055: 0.187937
# Cost after iteration 1056: 0.187867
# Cost after iteration 1057: 0.187798
# Cost after iteration 1058: 0.187732
# Cost after iteration 1059: 0.187667
# Cost after iteration 1060: 0.187604
# Cost after iteration 1061: 0.187543
# Cost after iteration 1062: 0.187483
# Cost after iteration 1063: 0.187425
# Cost after iteration 1064: 0.187369
# Cost after iteration 1065: 0.187314
# Cost after iteration 1066: 0.187260
# Cost after iteration 1067: 0.187208
# Cost after iteration 1068: 0.187157
# Cost after iteration 1069: 0.187107
# Cost after iteration 1070: 0.187059
# Cost after iteration 1071: 0.187011
# Cost after iteration 1072: 0.186965
# Cost after iteration 1073: 0.186920
# Cost after iteration 1074: 0.186876
# Cost after iteration 1075: 0.186832
# Cost after iteration 1076: 0.186790
# Cost after iteration 1077: 0.186748
# Cost after iteration 1078: 0.186708
# Cost after iteration 1079: 0.186668
# Cost after iteration 1080: 0.186629
# Cost after iteration 1081: 0.186591
# Cost after iteration 1082: 0.186554
# Cost after iteration 1083: 0.186518
# Cost after iteration 1084: 0.186482
# Cost after iteration 1085: 0.186447
# Cost after iteration 1086: 0.186414
# Cost after iteration 1087: 0.186382
# Cost after iteration 1088: 0.186352
# Cost after iteration 1089: 0.186327
# Cost after iteration 1090: 0.186307
# Cost after iteration 1091: 0.186300
# Cost after iteration 1092: 0.186316
# Cost after iteration 1093: 0.186374
# Cost after iteration 1094: 0.186518
# Cost after iteration 1095: 0.186822
# Cost after iteration 1096: 0.187475
# Cost after iteration 1097: 0.188749
# Cost after iteration 1098: 0.191546
# Cost after iteration 1099: 0.196912
# Cost after iteration 1100: 0.210407
# Cost after iteration 1101: 0.238074
# Cost after iteration 1102: 0.339252
# Cost after iteration 1103: 0.463814
# Cost after iteration 1104: 0.716410
# Cost after iteration 1105: 0.341144
# Cost after iteration 1106: 0.461653
# Cost after iteration 1107: 0.306534
# Cost after iteration 1108: 0.324018
# Cost after iteration 1109: 0.226964
# Cost after iteration 1110: 0.216429
# Cost after iteration 1111: 0.202872
# Cost after iteration 1112: 0.198810
# Cost after iteration 1113: 0.195712
# Cost after iteration 1114: 0.194387
# Cost after iteration 1115: 0.193505
# Cost after iteration 1116: 0.192982
# Cost after iteration 1117: 0.192585
# Cost after iteration 1118: 0.192271
# Cost after iteration 1119: 0.191996
# Cost after iteration 1120: 0.191747
# Cost after iteration 1121: 0.191517
# Cost after iteration 1122: 0.191300
# Cost after iteration 1123: 0.191095
# Cost after iteration 1124: 0.190899
# Cost after iteration 1125: 0.190713
# Cost after iteration 1126: 0.190535
# Cost after iteration 1127: 0.190365
# Cost after iteration 1128: 0.190202
# Cost after iteration 1129: 0.190046
# Cost after iteration 1130: 0.189896
# Cost after iteration 1131: 0.189752
# Cost after iteration 1132: 0.189614
# Cost after iteration 1133: 0.189482
# Cost after iteration 1134: 0.189355
# Cost after iteration 1135: 0.189232
# Cost after iteration 1136: 0.189114
# Cost after iteration 1137: 0.189001
# Cost after iteration 1138: 0.188892
# Cost after iteration 1139: 0.188786
# Cost after iteration 1140: 0.188685
# Cost after iteration 1141: 0.188587
# Cost after iteration 1142: 0.188492
# Cost after iteration 1143: 0.188401
# Cost after iteration 1144: 0.188312
# Cost after iteration 1145: 0.188227
# Cost after iteration 1146: 0.188144
# Cost after iteration 1147: 0.188064
# Cost after iteration 1148: 0.187987
# Cost after iteration 1149: 0.187912
# Cost after iteration 1150: 0.187839
# Cost after iteration 1151: 0.187769
# Cost after iteration 1152: 0.187700
# Cost after iteration 1153: 0.187634
# Cost after iteration 1154: 0.187570
# Cost after iteration 1155: 0.187507
# Cost after iteration 1156: 0.187446
# Cost after iteration 1157: 0.187388
# Cost after iteration 1158: 0.187330
# Cost after iteration 1159: 0.187274
# Cost after iteration 1160: 0.187220
# Cost after iteration 1161: 0.187167
# Cost after iteration 1162: 0.187116
# Cost after iteration 1163: 0.187066
# Cost after iteration 1164: 0.187017
# Cost after iteration 1165: 0.186970
# Cost after iteration 1166: 0.186924
# Cost after iteration 1167: 0.186879
# Cost after iteration 1168: 0.186835
# Cost after iteration 1169: 0.186792
# Cost after iteration 1170: 0.186750
# Cost after iteration 1171: 0.186710
# Cost after iteration 1172: 0.186670
# Cost after iteration 1173: 0.186632
# Cost after iteration 1174: 0.186595
# Cost after iteration 1175: 0.186560
# Cost after iteration 1176: 0.186526
# Cost after iteration 1177: 0.186495
# Cost after iteration 1178: 0.186468
# Cost after iteration 1179: 0.186446
# Cost after iteration 1180: 0.186433
# Cost after iteration 1181: 0.186432
# Cost after iteration 1182: 0.186454
# Cost after iteration 1183: 0.186508
# Cost after iteration 1184: 0.186631
# Cost after iteration 1185: 0.186841
# Cost after iteration 1186: 0.187268
# Cost after iteration 1187: 0.187939
# Cost after iteration 1188: 0.189355
# Cost after iteration 1189: 0.191460
# Cost after iteration 1190: 0.196404
# Cost after iteration 1191: 0.203349
# Cost after iteration 1192: 0.222253
# Cost after iteration 1193: 0.244299
# Cost after iteration 1194: 0.321408
# Cost after iteration 1195: 0.368313
# Cost after iteration 1196: 0.690487
# Cost after iteration 1197: 0.535626
# Cost after iteration 1198: 0.747676
# Cost after iteration 1199: 0.262976
# Cost after iteration 1200: 0.230837
# Cost after iteration 1201: 0.206912
# Cost after iteration 1202: 0.199784
# Cost after iteration 1203: 0.197000
# Cost after iteration 1204: 0.195902
# Cost after iteration 1205: 0.195300
# Cost after iteration 1206: 0.194868
# Cost after iteration 1207: 0.194499
# Cost after iteration 1208: 0.194161
# Cost after iteration 1209: 0.193844
# Cost after iteration 1210: 0.193543
# Cost after iteration 1211: 0.193257
# Cost after iteration 1212: 0.192985
# Cost after iteration 1213: 0.192725
# Cost after iteration 1214: 0.192477
# Cost after iteration 1215: 0.192240
# Cost after iteration 1216: 0.192014
# Cost after iteration 1217: 0.191798
# Cost after iteration 1218: 0.191592
# Cost after iteration 1219: 0.191394
# Cost after iteration 1220: 0.191205
# Cost after iteration 1221: 0.191024
# Cost after iteration 1222: 0.190850
# Cost after iteration 1223: 0.190684
# Cost after iteration 1224: 0.190524
# Cost after iteration 1225: 0.190371
# Cost after iteration 1226: 0.190224
# Cost after iteration 1227: 0.190082
# Cost after iteration 1228: 0.189946
# Cost after iteration 1229: 0.189815
# Cost after iteration 1230: 0.189689
# Cost after iteration 1231: 0.189568
# Cost after iteration 1232: 0.189451
# Cost after iteration 1233: 0.189338
# Cost after iteration 1234: 0.189229
# Cost after iteration 1235: 0.189124
# Cost after iteration 1236: 0.189023
# Cost after iteration 1237: 0.188925
# Cost after iteration 1238: 0.188830
# Cost after iteration 1239: 0.188738
# Cost after iteration 1240: 0.188650
# Cost after iteration 1241: 0.188564
# Cost after iteration 1242: 0.188481
# Cost after iteration 1243: 0.188400
# Cost after iteration 1244: 0.188322
# Cost after iteration 1245: 0.188246
# Cost after iteration 1246: 0.188173
# Cost after iteration 1247: 0.188102
# Cost after iteration 1248: 0.188033
# Cost after iteration 1249: 0.187966
# Cost after iteration 1250: 0.187900
# Cost after iteration 1251: 0.187837
# Cost after iteration 1252: 0.187775
# Cost after iteration 1253: 0.187715
# Cost after iteration 1254: 0.187657
# Cost after iteration 1255: 0.187600
# Cost after iteration 1256: 0.187545
# Cost after iteration 1257: 0.187491
# Cost after iteration 1258: 0.187439
# Cost after iteration 1259: 0.187388
# Cost after iteration 1260: 0.187338
# Cost after iteration 1261: 0.187290
# Cost after iteration 1262: 0.187242
# Cost after iteration 1263: 0.187196
# Cost after iteration 1264: 0.187151
# Cost after iteration 1265: 0.187107
# Cost after iteration 1266: 0.187064
# Cost after iteration 1267: 0.187022
# Cost after iteration 1268: 0.186981
# Cost after iteration 1269: 0.186941
# Cost after iteration 1270: 0.186902
# Cost after iteration 1271: 0.186864
# Cost after iteration 1272: 0.186827
# Cost after iteration 1273: 0.186790
# Cost after iteration 1274: 0.186754
# Cost after iteration 1275: 0.186719
# Cost after iteration 1276: 0.186685
# Cost after iteration 1277: 0.186651
# Cost after iteration 1278: 0.186619
# Cost after iteration 1279: 0.186586
# Cost after iteration 1280: 0.186555
# Cost after iteration 1281: 0.186524
# Cost after iteration 1282: 0.186494
# Cost after iteration 1283: 0.186464
# Cost after iteration 1284: 0.186435
# Cost after iteration 1285: 0.186406
# Cost after iteration 1286: 0.186378
# Cost after iteration 1287: 0.186351
# Cost after iteration 1288: 0.186324
# Cost after iteration 1289: 0.186297
# Cost after iteration 1290: 0.186271
# Cost after iteration 1291: 0.186245
# Cost after iteration 1292: 0.186220
# Cost after iteration 1293: 0.186196
# Cost after iteration 1294: 0.186171
# Cost after iteration 1295: 0.186147
# Cost after iteration 1296: 0.186124
# Cost after iteration 1297: 0.186101
# Cost after iteration 1298: 0.186078
# Cost after iteration 1299: 0.186056
# Cost after iteration 1300: 0.186034
# Cost after iteration 1301: 0.186012
# Cost after iteration 1302: 0.185991
# Cost after iteration 1303: 0.185970
# Cost after iteration 1304: 0.185950
# Cost after iteration 1305: 0.185931
# Cost after iteration 1306: 0.185914
# Cost after iteration 1307: 0.185900
# Cost after iteration 1308: 0.185891
# Cost after iteration 1309: 0.185892
# Cost after iteration 1310: 0.185914
# Cost after iteration 1311: 0.185973
# Cost after iteration 1312: 0.186117
# Cost after iteration 1313: 0.186403
# Cost after iteration 1314: 0.187065
# Cost after iteration 1315: 0.188270
# Cost after iteration 1316: 0.191318
# Cost after iteration 1317: 0.196500
# Cost after iteration 1318: 0.211784
# Cost after iteration 1319: 0.233198
# Cost after iteration 1320: 0.310333
# Cost after iteration 1321: 0.330546
# Cost after iteration 1322: 0.560313
# Cost after iteration 1323: 0.467135
# Cost after iteration 1324: 0.789529
# Cost after iteration 1325: 0.271435
# Cost after iteration 1326: 0.257463
# Cost after iteration 1327: 0.224770
# Cost after iteration 1328: 0.212566
# Cost after iteration 1329: 0.203290
# Cost after iteration 1330: 0.198343
# Cost after iteration 1331: 0.195588
# Cost after iteration 1332: 0.194143
# Cost after iteration 1333: 0.193311
# Cost after iteration 1334: 0.192786
# Cost after iteration 1335: 0.192397
# Cost after iteration 1336: 0.192080
# Cost after iteration 1337: 0.191801
# Cost after iteration 1338: 0.191548
# Cost after iteration 1339: 0.191313
# Cost after iteration 1340: 0.191092
# Cost after iteration 1341: 0.190883
# Cost after iteration 1342: 0.190686
# Cost after iteration 1343: 0.190499
# Cost after iteration 1344: 0.190321
# Cost after iteration 1345: 0.190152
# Cost after iteration 1346: 0.189990
# Cost after iteration 1347: 0.189837
# Cost after iteration 1348: 0.189691
# Cost after iteration 1349: 0.189551
# Cost after iteration 1350: 0.189418
# Cost after iteration 1351: 0.189290
# Cost after iteration 1352: 0.189169
# Cost after iteration 1353: 0.189052
# Cost after iteration 1354: 0.188941
# Cost after iteration 1355: 0.188834
# Cost after iteration 1356: 0.188731
# Cost after iteration 1357: 0.188633
# Cost after iteration 1358: 0.188539
# Cost after iteration 1359: 0.188448
# Cost after iteration 1360: 0.188361
# Cost after iteration 1361: 0.188277
# Cost after iteration 1362: 0.188196
# Cost after iteration 1363: 0.188119
# ...
# Cost after iteration 2560: 0.189606
# Cost after iteration 2561: 0.189469
# Cost after iteration 2562: 0.189354
# Cost after iteration 2563: 0.189246
# Cost after iteration 2564: 0.189149
# Cost after iteration 2565: 0.189057
# Cost after iteration 2566: 0.188971
# Cost after iteration 2567: 0.188889
# Cost after iteration 2568: 0.188811
# Cost after iteration 2569: 0.188737
# Cost after iteration 2570: 0.188665
# Cost after iteration 2571: 0.188597
# Cost after iteration 2572: 0.188530
# Cost after iteration 2573: 0.188466
# Cost after iteration 2574: 0.188405
# Cost after iteration 2575: 0.188345
# Cost after iteration 2576: 0.188288
# Cost after iteration 2577: 0.188232
# Cost after iteration 2578: 0.188178
# Cost after iteration 2579: 0.188125
# Cost after iteration 2580: 0.188075
# Cost after iteration 2581: 0.188025
# Cost after iteration 2582: 0.187978
# Cost after iteration 2583: 0.187932
# Cost after iteration 2584: 0.187887
# Cost after iteration 2585: 0.187844
# Cost after iteration 2586: 0.187802
# Cost after iteration 2587: 0.187762
# Cost after iteration 2588: 0.187723
# Cost after iteration 2589: 0.187686
# Cost after iteration 2590: 0.187651
# Cost after iteration 2591: 0.187617
# Cost after iteration 2592: 0.187586
# Cost after iteration 2593: 0.187557
# Cost after iteration 2594: 0.187532
# Cost after iteration 2595: 0.187510
# Cost after iteration 2596: 0.187494
# Cost after iteration 2597: 0.187482
# Cost after iteration 2598: 0.187484
# Cost after iteration 2599: 0.187490
# Cost after iteration 2600: 0.187524
# Cost after iteration 2601: 0.187564
# Cost after iteration 2602: 0.187663
# Cost after iteration 2603: 0.187769
# Cost after iteration 2604: 0.188010
# Cost after iteration 2605: 0.188251
# Cost after iteration 2606: 0.188821
# Cost after iteration 2607: 0.189353
# Cost after iteration 2608: 0.190742
# Cost after iteration 2609: 0.191950
# Cost after iteration 2610: 0.195540
# Cost after iteration 2611: 0.198434
# Cost after iteration 2612: 0.208192
# Cost after iteration 2613: 0.213746
# Cost after iteration 2614: 0.238175
# Cost after iteration 2615: 0.233833
# Cost after iteration 2616: 0.273201
# Cost after iteration 2617: 0.238828
# Cost after iteration 2618: 0.265363
# Cost after iteration 2619: 0.223885
# Cost after iteration 2620: 0.230691
# Cost after iteration 2621: 0.212884
# Cost after iteration 2622: 0.214959
# Cost after iteration 2623: 0.208159
# Cost after iteration 2624: 0.209444
# Cost after iteration 2625: 0.206250
# Cost after iteration 2626: 0.207736
# Cost after iteration 2627: 0.206069
# Cost after iteration 2628: 0.208000
# Cost after iteration 2629: 0.206745
# Cost after iteration 2630: 0.208912
# Cost after iteration 2631: 0.207384
# Cost after iteration 2632: 0.209323
# Cost after iteration 2633: 0.207171
# Cost after iteration 2634: 0.208337
# Cost after iteration 2635: 0.205551
# Cost after iteration 2636: 0.205594
# Cost after iteration 2637: 0.202526
# Cost after iteration 2638: 0.201608
# Cost after iteration 2639: 0.198809
# Cost after iteration 2640: 0.197520
# Cost after iteration 2641: 0.195384
# Cost after iteration 2642: 0.194246
# Cost after iteration 2643: 0.192819
# Cost after iteration 2644: 0.192009
# Cost after iteration 2645: 0.191121
# Cost after iteration 2646: 0.190597
# Cost after iteration 2647: 0.190050
# Cost after iteration 2648: 0.189721
# Cost after iteration 2649: 0.189376
# Cost after iteration 2650: 0.189167
# Cost after iteration 2651: 0.188941
# Cost after iteration 2652: 0.188805
# Cost after iteration 2653: 0.188649
# Cost after iteration 2654: 0.188560
# Cost after iteration 2655: 0.188448
# Cost after iteration 2656: 0.188391
# Cost after iteration 2657: 0.188309
# Cost after iteration 2658: 0.188278
# Cost after iteration 2659: 0.188217
# Cost after iteration 2660: 0.188210
# Cost after iteration 2661: 0.188169
# Cost after iteration 2662: 0.188189
# Cost after iteration 2663: 0.188167
# Cost after iteration 2664: 0.188221
# Cost after iteration 2665: 0.188222
# Cost after iteration 2666: 0.188327
# Cost after iteration 2667: 0.188359
# Cost after iteration 2668: 0.188543
# Cost after iteration 2669: 0.188621
# Cost after iteration 2670: 0.188936
# Cost after iteration 2671: 0.189087
# Cost after iteration 2672: 0.189636
# Cost after iteration 2673: 0.189909
# Cost after iteration 2674: 0.190897
# Cost after iteration 2675: 0.191390
# Cost after iteration 2676: 0.193248
# Cost after iteration 2677: 0.194160
# Cost after iteration 2678: 0.197831
# Cost after iteration 2679: 0.199488
# Cost after iteration 2680: 0.206912
# Cost after iteration 2681: 0.209047
# Cost after iteration 2682: 0.222991
# Cost after iteration 2683: 0.220962
# Cost after iteration 2684: 0.240987
# Cost after iteration 2685: 0.227438
# Cost after iteration 2686: 0.245653
# Cost after iteration 2687: 0.226940
# Cost after iteration 2688: 0.239233
# Cost after iteration 2689: 0.226595
# Cost after iteration 2690: 0.237244
# Cost after iteration 2691: 0.231548
# Cost after iteration 2692: 0.246621
# Cost after iteration 2693: 0.244902
# Cost after iteration 2694: 0.271929
# Cost after iteration 2695: 0.265086
# Cost after iteration 2696: 0.301425
# Cost after iteration 2697: 0.269396
# Cost after iteration 2698: 0.286786
# Cost after iteration 2699: 0.244100
# Cost after iteration 2700: 0.235719
# Cost after iteration 2701: 0.213714
# Cost after iteration 2702: 0.204304
# Cost after iteration 2703: 0.196996
# Cost after iteration 2704: 0.194174
# Cost after iteration 2705: 0.192229
# Cost after iteration 2706: 0.191435
# Cost after iteration 2707: 0.190767
# Cost after iteration 2708: 0.190425
# Cost after iteration 2709: 0.190111
# Cost after iteration 2710: 0.189910
# Cost after iteration 2711: 0.189724
# Cost after iteration 2712: 0.189582
# Cost after iteration 2713: 0.189450
# Cost after iteration 2714: 0.189338
# Cost after iteration 2715: 0.189232
# Cost after iteration 2716: 0.189137
# Cost after iteration 2717: 0.189046
# Cost after iteration 2718: 0.188961
# Cost after iteration 2719: 0.188880
# Cost after iteration 2720: 0.188803
# Cost after iteration 2721: 0.188729
# Cost after iteration 2722: 0.188658
# Cost after iteration 2723: 0.188590
# Cost after iteration 2724: 0.188525
# Cost after iteration 2725: 0.188461
# Cost after iteration 2726: 0.188400
# Cost after iteration 2727: 0.188341
# Cost after iteration 2728: 0.188284
# Cost after iteration 2729: 0.188228
# Cost after iteration 2730: 0.188175
# Cost after iteration 2731: 0.188123
# Cost after iteration 2732: 0.188072
# Cost after iteration 2733: 0.188024
# Cost after iteration 2734: 0.187976
# Cost after iteration 2735: 0.187930
# Cost after iteration 2736: 0.187886
# Cost after iteration 2737: 0.187843
# Cost after iteration 2738: 0.187802
# Cost after iteration 2739: 0.187762
# Cost after iteration 2740: 0.187724
# Cost after iteration 2741: 0.187687
# Cost after iteration 2742: 0.187652
# Cost after iteration 2743: 0.187619
# Cost after iteration 2744: 0.187589
# Cost after iteration 2745: 0.187560
# Cost after iteration 2746: 0.187536
# Cost after iteration 2747: 0.187514
# Cost after iteration 2748: 0.187501
# Cost after iteration 2749: 0.187490
# Cost after iteration 2750: 0.187494
# Cost after iteration 2751: 0.187503
# Cost after iteration 2752: 0.187541
# Cost after iteration 2753: 0.187586
# Cost after iteration 2754: 0.187696
# Cost after iteration 2755: 0.187812
# Cost after iteration 2756: 0.188076
# Cost after iteration 2757: 0.188339
# Cost after iteration 2758: 0.188966
# Cost after iteration 2759: 0.189546
# Cost after iteration 2760: 0.191082
# Cost after iteration 2761: 0.192410
# Cost after iteration 2762: 0.196413
# Cost after iteration 2763: 0.199600
# Cost after iteration 2764: 0.210501
# Cost after iteration 2765: 0.216098
# Cost after iteration 2766: 0.242744
# Cost after iteration 2767: 0.235522
# Cost after iteration 2768: 0.275146
# Cost after iteration 2769: 0.237754
# Cost after iteration 2770: 0.261436
# Cost after iteration 2771: 0.221907
# Cost after iteration 2772: 0.227563
# Cost after iteration 2773: 0.211828
# Cost after iteration 2774: 0.213588
# Cost after iteration 2775: 0.207307
# Cost after iteration 2776: 0.208377
# Cost after iteration 2777: 0.205360
# Cost after iteration 2778: 0.206599
# Cost after iteration 2779: 0.204973
# Cost after iteration 2780: 0.206552
# Cost after iteration 2781: 0.205300
# Cost after iteration 2782: 0.206990
# Cost after iteration 2783: 0.205523
# Cost after iteration 2784: 0.206930
# Cost after iteration 2785: 0.204994
# Cost after iteration 2786: 0.205728
# Cost after iteration 2787: 0.203359
# Cost after iteration 2788: 0.203244
# Cost after iteration 2789: 0.200731
# Cost after iteration 2790: 0.199948
# Cost after iteration 2791: 0.197677
# Cost after iteration 2792: 0.196646
# Cost after iteration 2793: 0.194876
# Cost after iteration 2794: 0.193946
# Cost after iteration 2795: 0.192708
# Cost after iteration 2796: 0.192011
# Cost after iteration 2797: 0.191196
# Cost after iteration 2798: 0.190718
# Cost after iteration 2799: 0.190189
# Cost after iteration 2800: 0.189874
# Cost after iteration 2801: 0.189526
# Cost after iteration 2802: 0.189319
# Cost after iteration 2803: 0.189084
# Cost after iteration 2804: 0.188948
# Cost after iteration 2805: 0.188783
# Cost after iteration 2806: 0.188696
# Cost after iteration 2807: 0.188577
# Cost after iteration 2808: 0.188526
# Cost after iteration 2809: 0.188440
# Cost after iteration 2810: 0.188419
# Cost after iteration 2811: 0.188359
# Cost after iteration 2812: 0.188367
# Cost after iteration 2813: 0.188330
# Cost after iteration 2814: 0.188374
# Cost after iteration 2815: 0.188361
# Cost after iteration 2816: 0.188452
# Cost after iteration 2817: 0.188469
# Cost after iteration 2818: 0.188631
# Cost after iteration 2819: 0.188689
# Cost after iteration 2820: 0.188963
# Cost after iteration 2821: 0.189082
# Cost after iteration 2822: 0.189548
# Cost after iteration 2823: 0.189767
# Cost after iteration 2824: 0.190579
# Cost after iteration 2825: 0.190970
# Cost after iteration 2826: 0.192443
# Cost after iteration 2827: 0.193149
# Cost after iteration 2828: 0.195952
# Cost after iteration 2829: 0.197236
# Cost after iteration 2830: 0.202781
# Cost after iteration 2831: 0.204803
# Cost after iteration 2832: 0.215526
# Cost after iteration 2833: 0.216211
# Cost after iteration 2834: 0.233695
# Cost after iteration 2835: 0.225777
# Cost after iteration 2836: 0.245311
# Cost after iteration 2837: 0.228281
# Cost after iteration 2838: 0.243063
# Cost after iteration 2839: 0.227970
# Cost after iteration 2840: 0.239550
# Cost after iteration 2841: 0.231583
# Cost after iteration 2842: 0.245904
# Cost after iteration 2843: 0.242931
# Cost after iteration 2844: 0.267529
# Cost after iteration 2845: 0.262374
# Cost after iteration 2846: 0.298470
# Cost after iteration 2847: 0.271293
# Cost after iteration 2848: 0.293637
# Cost after iteration 2849: 0.249880
# Cost after iteration 2850: 0.244507
# Cost after iteration 2851: 0.218729
# Cost after iteration 2852: 0.208133
# Cost after iteration 2853: 0.198904
# Cost after iteration 2854: 0.195256
# Cost after iteration 2855: 0.192754
# Cost after iteration 2856: 0.191766
# Cost after iteration 2857: 0.190959
# Cost after iteration 2858: 0.190563
# Cost after iteration 2859: 0.190207
# Cost after iteration 2860: 0.189987
# Cost after iteration 2861: 0.189786
# Cost after iteration 2862: 0.189637
# Cost after iteration 2863: 0.189499
# Cost after iteration 2864: 0.189383
# Cost after iteration 2865: 0.189275
# Cost after iteration 2866: 0.189177
# Cost after iteration 2867: 0.189085
# Cost after iteration 2868: 0.188999
# Cost after iteration 2869: 0.188917
# Cost after iteration 2870: 0.188839
# Cost after iteration 2871: 0.188764
# Cost after iteration 2872: 0.188692
# Cost after iteration 2873: 0.188623
# Cost after iteration 2874: 0.188557
# Cost after iteration 2875: 0.188493
# Cost after iteration 2876: 0.188431
# Cost after iteration 2877: 0.188371
# Cost after iteration 2878: 0.188313
# Cost after iteration 2879: 0.188257
# Cost after iteration 2880: 0.188203
# Cost after iteration 2881: 0.188151
# Cost after iteration 2882: 0.188100
# Cost after iteration 2883: 0.188050
# Cost after iteration 2884: 0.188002
# Cost after iteration 2885: 0.187956
# Cost after iteration 2886: 0.187911
# Cost after iteration 2887: 0.187867
# Cost after iteration 2888: 0.187825
# Cost after iteration 2889: 0.187784
# Cost after iteration 2890: 0.187744
# Cost after iteration 2891: 0.187706
# Cost after iteration 2892: 0.187670
# Cost after iteration 2893: 0.187634
# Cost after iteration 2894: 0.187601
# Cost after iteration 2895: 0.187570
# Cost after iteration 2896: 0.187541
# Cost after iteration 2897: 0.187515
# Cost after iteration 2898: 0.187493
# Cost after iteration 2899: 0.187474
# Cost after iteration 2900: 0.187463
# Cost after iteration 2901: 0.187456
# Cost after iteration 2902: 0.187466
# Cost after iteration 2903: 0.187481
# Cost after iteration 2904: 0.187530
# Cost after iteration 2905: 0.187587
# Cost after iteration 2906: 0.187720
# Cost after iteration 2907: 0.187863
# Cost after iteration 2908: 0.188184
# Cost after iteration 2909: 0.188504
# Cost after iteration 2910: 0.189276
# Cost after iteration 2911: 0.189992
# Cost after iteration 2912: 0.191929
# Cost after iteration 2913: 0.193605
# Cost after iteration 2914: 0.198788
# Cost after iteration 2915: 0.202802
# Cost after iteration 2916: 0.216978
# Cost after iteration 2917: 0.222069
# Cost after iteration 2918: 0.254484
# Cost after iteration 2919: 0.239360
# Cost after iteration 2920: 0.278805
# Cost after iteration 2921: 0.235042
# Cost after iteration 2922: 0.252515
# Cost after iteration 2923: 0.218483
# Cost after iteration 2924: 0.222342
# Cost after iteration 2925: 0.210621
# Cost after iteration 2926: 0.212162
# Cost after iteration 2927: 0.207209
# Cost after iteration 2928: 0.208513
# Cost after iteration 2929: 0.206129
# Cost after iteration 2930: 0.207824
# Cost after iteration 2931: 0.206433
# Cost after iteration 2932: 0.208535
# Cost after iteration 2933: 0.207204
# Cost after iteration 2934: 0.209355
# Cost after iteration 2935: 0.207541
# Cost after iteration 2936: 0.209199
# Cost after iteration 2937: 0.206698
# Cost after iteration 2938: 0.207353
# Cost after iteration 2939: 0.204334
# Cost after iteration 2940: 0.203849
# Cost after iteration 2941: 0.200808
# Cost after iteration 2942: 0.199606
# Cost after iteration 2943: 0.197076
# Cost after iteration 2944: 0.195795
# Cost after iteration 2945: 0.194005
# Cost after iteration 2946: 0.193011
# Cost after iteration 2947: 0.191870
# Cost after iteration 2948: 0.191204
# Cost after iteration 2949: 0.190506
# Cost after iteration 2950: 0.190085
# Cost after iteration 2951: 0.189654
# Cost after iteration 2952: 0.189390
# Cost after iteration 2953: 0.189114
# Cost after iteration 2954: 0.188944
# Cost after iteration 2955: 0.188758
# Cost after iteration 2956: 0.188646
# Cost after iteration 2957: 0.188515
# Cost after iteration 2958: 0.188441
# Cost after iteration 2959: 0.188346
# Cost after iteration 2960: 0.188299
# Cost after iteration 2961: 0.188228
# Cost after iteration 2962: 0.188203
# Cost after iteration 2963: 0.188152
# Cost after iteration 2964: 0.188150
# Cost after iteration 2965: 0.188116
# Cost after iteration 2966: 0.188141
# Cost after iteration 2967: 0.188126
# Cost after iteration 2968: 0.188187
# Cost after iteration 2969: 0.188196
# Cost after iteration 2970: 0.188310
# Cost after iteration 2971: 0.188352
# Cost after iteration 2972: 0.188552
# Cost after iteration 2973: 0.188644
# Cost after iteration 2974: 0.188990
# Cost after iteration 2975: 0.189163
# Cost after iteration 2976: 0.189772
# Cost after iteration 2977: 0.190084
# Cost after iteration 2978: 0.191195
# Cost after iteration 2979: 0.191762
# Cost after iteration 2980: 0.193887
# Cost after iteration 2981: 0.194946
# Cost after iteration 2982: 0.199213
# Cost after iteration 2983: 0.201105
# Cost after iteration 2984: 0.209774
# Cost after iteration 2985: 0.211756
# Cost after iteration 2986: 0.227562
# Cost after iteration 2987: 0.223356
# Cost after iteration 2988: 0.244193
# Cost after iteration 2989: 0.228028
# Cost after iteration 2990: 0.245140
# Cost after iteration 2991: 0.226653
# Cost after iteration 2992: 0.238085
# Cost after iteration 2993: 0.227014
# Cost after iteration 2994: 0.237967
# Cost after iteration 2995: 0.233378
# Cost after iteration 2996: 0.250186
# Cost after iteration 2997: 0.248621
# Cost after iteration 2998: 0.278514
# Cost after iteration 2999: 0.267954
# W1 = [[-2.56050135  1.71264409]
#  [-2.02083355  2.0025167 ]]
# b1 = [[-6.37231907]
#  [ 4.84119037]]
# W2 = [[-7.09142417  7.23431582]]
# b2 = [[-3.53545048]]

# %% [markdown]
# ##### __Expected Output__
# Note: the actual values can be different!
#
# ```Python
# Cost after iteration 0: 0.693148
# Cost after iteration 1: 0.693147
# Cost after iteration 2: 0.693147
# Cost after iteration 3: 0.693147
# Cost after iteration 4: 0.693147
# Cost after iteration 5: 0.693147
# ...
# Cost after iteration 2995: 0.209524
# Cost after iteration 2996: 0.208025
# Cost after iteration 2997: 0.210427
# Cost after iteration 2998: 0.208929
# Cost after iteration 2999: 0.211306
# W1 = [[ 2.14274251 -1.93155541]
#  [ 2.20268789 -2.1131799 ]]
# b1 = [[-4.83079243]
#  [ 6.2845223 ]]
# W2 = [[-7.21370685  7.0898022 ]]
# b2 = [[-3.48755239]]
# ```

# %%
# Note: 
# Actual values are not checked here in the unit tests (due to random initialization).
w3_unittest.test_nn_model(nn_model)
# Out:
#  All tests passed

# %% [markdown]
# The final model parameters can be used to find the boundary line and for making predictions.

# %% [markdown]
# <a name='ex08'></a>
# ### Exercise 8
#
# Computes probabilities using forward propagation, and make classification to 0/1 using 0.5 as the threshold.

# %%
# GRADED FUNCTION: predict

def predict(X, parameters):
    """
    Using the learned parameters, predicts a class for each example in X
    
    Arguments:
    parameters -- python dictionary containing your parameters 
    X -- input data of size (n_x, m)
    
    Returns
    predictions -- vector of predictions of our model (blue: 0 / red: 1)
    """
    
    ### START CODE HERE ### (≈ 2 lines of code)
    A2, cache = forward_propagation(X, parameters)
    predictions = (A2 > 0.5)
    ### END CODE HERE ###
    
    return predictions

# %%
X_pred = np.array([[2, 8, 2, 8], [2, 8, 8, 2]])
Y_pred = predict(X_pred, parameters)

print(f"Coordinates (in the columns):\n{X_pred}")
print(f"Predictions:\n{Y_pred}")
# Out:
# Coordinates (in the columns):
# [[2 8 2 8]
#  [2 8 8 2]]
# Predictions:
# [[ True  True False False]]

# %% [markdown]
# ##### __Expected Output__
#
# ```Python
# Coordinates (in the columns):
# [[2 8 2 8]
#  [2 8 8 2]]
# Predictions:
# [[ True  True False False]]
# ```

# %%
w3_unittest.test_predict(predict)
# Out:
#  All tests passed

# %% [markdown]
# Let's visualize the boundary line. Do not worry if you don't understand the function `plot_decision_boundary` line by line - it simply makes prediction for some points on the plane and plots them as a contour plot (just two colors - blue and red).

# %%
def plot_decision_boundary(predict, parameters, X, Y):
    # Define bounds of the domain.
    min1, max1 = X[0, :].min()-1, X[0, :].max()+1
    min2, max2 = X[1, :].min()-1, X[1, :].max()+1
    # Define the x and y scale.
    x1grid = np.arange(min1, max1, 0.1)
    x2grid = np.arange(min2, max2, 0.1)
    # Create all of the lines and rows of the grid.
    xx, yy = np.meshgrid(x1grid, x2grid)
    # Flatten each grid to a vector.
    r1, r2 = xx.flatten(), yy.flatten()
    r1, r2 = r1.reshape((1, len(r1))), r2.reshape((1, len(r2)))
    # Vertical stack vectors to create x1,x2 input for the model.
    grid = np.vstack((r1,r2))
    # Make predictions for the grid.
    predictions = predict(grid, parameters)
    # Reshape the predictions back into a grid.
    zz = predictions.reshape(xx.shape)
    # Plot the grid of x, y and z values as a surface.
    plt.contourf(xx, yy, zz, cmap=plt.cm.Spectral.reversed())
    plt.scatter(X[0, :], X[1, :], c=Y, cmap=colors.ListedColormap(['blue', 'red']));

# Plot the decision boundary.
plot_decision_boundary(predict, parameters, X, Y)
plt.title("Decision Boundary for hidden layer size " + str(n_h))
# Out:
# Text(0.5, 1.0, 'Decision Boundary for hidden layer size 2')

# %% [markdown]
# That's great, you can see that more complicated classification problems can be solved with two layer neural network!

# %% [markdown]
# <a name='4'></a>
# ## 4 - Optional: Other Dataset

# %% [markdown]
# Build a slightly different dataset:

# %%
n_samples = 2000
samples, labels = make_blobs(n_samples=n_samples, 
                             centers=([2.5, 3], [6.7, 7.9], [2.1, 7.9], [7.4, 2.8]), 
                             cluster_std=1.1,
                             random_state=0)
labels[(labels == 0)] = 0
labels[(labels == 1)] = 1
labels[(labels == 2) | (labels == 3)] = 1
X_2 = np.transpose(samples)
Y_2 = labels.reshape((1,n_samples))

plt.scatter(X_2[0, :], X_2[1, :], c=Y_2, cmap=colors.ListedColormap(['blue', 'red']));

# %% [markdown]
# Notice that when building your neural network, a number of the nodes in the hidden layer could be taken as a parameter. Try to change this parameter and investigate the results:

# %%
# parameters_2 = nn_model(X_2, Y_2, n_h=1, num_iterations=3000, learning_rate=1.2, print_cost=False)
# parameters_2 = nn_model(X_2, Y_2, n_h=2, num_iterations=3000, learning_rate=1.2, print_cost=False)
parameters_2 = nn_model(X_2, Y_2, n_h=15, num_iterations=3000, learning_rate=1.2, print_cost=False)

# This function will call predict function 
plot_decision_boundary(predict, parameters_2, X_2, Y_2)
plt.title("Decision Boundary")
# Out:
# Text(0.5, 1.0, 'Decision Boundary')

# %% [markdown]
# You can see that there are some misclassified points - real-world datasets are usually linearly inseparable, and there will be a small percentage of errors. More than that, you do not want to build a model that fits too closely, almost exactly to a particular set of data - it may fail to predict future observations. This problem is known as **overfitting**.

# %% [markdown]
# Congrats on finishing this programming assignment!
